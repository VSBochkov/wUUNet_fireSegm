# %%
from validation import Validation
import numpy as np
import os
import json

# %%
# %matplotlib inline
np.set_printoptions(precision=49)

# %%
def evaluate():
    test_model_metrics = {}
    for dataset_variant in DATASET_VARIANTS:
        for comb_type in COMBINATION_TYPES:
            for ml_model_name in ML_MODELS:
                print(dataset_variant, comb_type)
                validation = Validation(dataset_variant, comb_type, input_size=INPUT_SIZE)
                for snapshot_variant in VARIANTS[ml_model_name]:
                    model_full_name = ml_model_name + '_' + snapshot_variant
                    test_model_metrics[model_full_name] = validation.calculate_thresholds(
                        ml_model_name, snapshot_variant
                    )
                #validation.draw_barchart(test_model_metrics)

        test_model_metrics_json = {
            key: [str(test_model_metrics[key][0]), str(test_model_metrics[key][1]), str(test_model_metrics[key][2]), 
                  str(test_model_metrics[key][3]), str(test_model_metrics[key][4]), str(test_model_metrics[key][5]), 
                  str(test_model_metrics[key][6]), str(test_model_metrics[key][7]), str(test_model_metrics[key][8])]
            for key in test_model_metrics
        }

        json.dump(test_model_metrics_json, 
                  open('output/evaluation/{}_{}/validation_metrics.json'.format(dataset_variant, comb_type), 'w'))

# %% [markdown]
# # Fullsize 448x448 models evaluation

# %%
ML_MODELS = [
    'unet_448_n3_fs_dice',
    'unet_448_n3_fs_jaccard'
]


INPUT_SIZE = (448, 448)

DATASET_VARIANTS = ['test']  #['train_test']

COMBINATION_TYPES = ['nonint']
print(COMBINATION_TYPES)

VARIANTS = {
    'unet_448_n3_fs_dice':    ['pretrained'],  #['acc', 'bce'],
    'unet_448_n3_fs_jaccard': ['pretrained']   #['mult_trainval_acc', 'loss']
}

evaluate()
# Out:
# ['nonint']
# test nonint
# [unet_448_n3_fs_dice_best_pretrained test, threshold = 0.52]:
# MULTICLASS DICE [val = 0.8536080718040466, std = 0.0908966138958931] JACCARD [val = 0.7664164900779724, std = 0.1159883439540863]
# BINARY DICE [val = 0.9145413041114807, std = 0.15112027525901794] JACCARD [val = 0.8652287125587463, std = 0.15631063282489777]
#
# test nonint
# [unet_448_n3_fs_jaccard_best_pretrained test, threshold = 0.37]:
# MULTICLASS DICE [val = 0.8589077591896057, std = 0.08980230987071991] JACCARD [val = 0.773259699344635, std = 0.11477012187242508]
# BINARY DICE [val = 0.9271300435066223, std = 0.12409736216068268] JACCARD [val = 0.8801120519638062, std = 0.1341768503189087]

# %% [markdown]
# # One-window 448x448 models evaluation

# %% [markdown]
# ###

# %%
ML_MODELS = [
    'unet_448_n3_ow_dice',
    'unet_448_n3_ow_jaccard'
]

INPUT_SIZE = (448, 448)

DATASET_VARIANTS = ['test']  #['train_test']

COMBINATION_TYPES = ['onewin']
print(COMBINATION_TYPES)

VARIANTS = {
    'unet_448_n3_ow_dice':    ['pretrained'],  #['acc', 'bce'],
    'unet_448_n3_ow_jaccard': ['pretrained']   #['mult_trainval_acc', 'loss']
}

evaluate()
# Out:
# ['onewin']
# test onewin
# [unet_448_n3_ow_dice_best_pretrained test, threshold = 0.66]:
# MULTICLASS DICE [val = 0.8512189984321594, std = 0.09945961833000183] JACCARD [val = 0.7656216025352478, std = 0.11992797255516052]
# BINARY DICE [val = 0.9174288511276245, std = 0.1503957360982895] JACCARD [val = 0.8689444661140442, std = 0.15789848566055298]
#
# test onewin
# [unet_448_n3_ow_jaccard_best_pretrained test, threshold = 0.8]:
# MULTICLASS DICE [val = 0.8336563110351562, std = 0.10693845897912979] JACCARD [val = 0.7451350092887878, std = 0.12248972803354263]
# BINARY DICE [val = 0.8877893686294556, std = 0.19573931396007538] JACCARD [val = 0.8344070315361023, std = 0.19957558810710907]

# %% [markdown]
# # Fullsize 224x224 models evaluation

# %%
ML_MODELS = [
    'unet_224_n3_fs_jaccard',
    'uunet_224_n3_fs_jaccard',
    'wuunet_224_n3_fs_jaccard'
]

INPUT_SIZE = (224, 224)

DATASET_VARIANTS = ['test']  #['train_test']

COMBINATION_TYPES = ['gauss_{}'.format(i) for i in range(1, 7)]
COMBINATION_TYPES.extend(['nonint', 'var_step', 'add', 'add_weight'])
print(COMBINATION_TYPES)

VARIANTS = {
    'unet_224_n3_fs_jaccard':   ['pretrained'],  #['mult_trainval_acc', 'loss']
    'uunet_224_n3_fs_jaccard':  ['pretrained'],  #['mult_acc', 'mult_loss', 'mult_trainval_acc']
    'wuunet_224_n3_fs_jaccard': ['pretrained']   #['mult_acc', 'mult_loss', 'mult_trainval_acc']
}

evaluate()
# Out:
# ['gauss_1', 'gauss_2', 'gauss_3', 'gauss_4', 'gauss_5', 'gauss_6', 'nonint', 'var_step', 'add', 'add_weight']
# test gauss_1
# [unet_224_n3_fs_jaccard_best_pretrained test, threshold = 1.78]:
# MULTICLASS DICE [val = 0.864700198173523, std = 0.10801218450069427] JACCARD [val = 0.789060115814209, std = 0.12087307125329971]
# BINARY DICE [val = 0.9202410578727722, std = 0.16582058370113373] JACCARD [val = 0.8782797455787659, std = 0.17084327340126038]
#
# test gauss_1
# [uunet_224_n3_fs_jaccard_best_pretrained test, threshold = 1.8800000000000001]:
# MULTICLASS DICE [val = 0.8726083636283875, std = 0.0950973778963089] JACCARD [val = 0.7963340878486633, std = 0.11281018704175949]
# BINARY DICE [val = 0.9345990419387817, std = 0.12514597177505493] JACCARD [val = 0.8930436968803406, std = 0.13195890188217163]
#
# test gauss_1
# [wuunet_224_n3_fs_jaccard_best_pretrained test, threshold = 1.82]:
# MULTICLASS DICE [val = 0.8773807883262634, std = 0.08878577500581741] JACCARD [val = 0.8003774285316467, std = 0.11246614158153534]
# BINARY DICE [val = 0.9520439505577087, std = 0.040140047669410706] JACCARD [val = 0.9110988974571228, std = 0.06865900754928589]
#
# test gauss_2
# [unet_224_n3_fs_jaccard_best_pretrained test, threshold = 1.44]:
# MULTICLASS DICE [val = 0.8656995892524719, std = 0.10515687614679337] JACCARD [val = 0.7902592420578003, std = 0.11835607141256332]
# BINARY DICE [val = 0.9207836389541626, std = 0.16582471132278442] JACCARD [val = 0.8792325258255005, std = 0.17083968222141266]
#
# test gauss_2
# [uunet_224_n3_fs_jaccard_best_pretrained test, threshold = 1.57]:
# MULTICLASS DICE [val = 0.8737722039222717, std = 0.09431014209985733] JACCARD [val = 0.797980010509491, std = 0.11185908317565918]
# BINARY DICE [val = 0.9362316727638245, std = 0.12317906320095062] JACCARD [val = 0.8956987261772156, std = 0.1300448775291443]
#
# test gauss_2
# [wuunet_224_n3_fs_jaccard_best_pretrained test, threshold = 1.47]:
# MULTICLASS DICE [val = 0.8779763579368591, std = 0.08846350014209747] JACCARD [val = 0.8011831045150757, std = 0.11219976842403412]
# BINARY DICE [val = 0.952633261680603, std = 0.04001744091510773] JACCARD [val = 0.9121538400650024, std = 0.06834544241428375]
#
# test gauss_3
# [unet_224_n3_fs_jaccard_best_pretrained test, threshold = 0.96]:
# MULTICLASS DICE [val = 0.8662923574447632, std = 0.10489240288734436] JACCARD [val = 0.7910966873168945, std = 0.11783858388662338]
# BINARY DICE [val = 0.9217561483383179, std = 0.16606326401233673] JACCARD [val = 0.880946695804596, std = 0.17091993987560272]
#
# test gauss_3
# [uunet_224_n3_fs_jaccard_best_pretrained test, threshold = 1.17]:
# MULTICLASS DICE [val = 0.8740100264549255, std = 0.09411728382110596] JACCARD [val = 0.7983009219169617, std = 0.11162468791007996]
# BINARY DICE [val = 0.9368780851364136, std = 0.12323281913995743] JACCARD [val = 0.8968562483787537, std = 0.13003219664096832]
#
# test gauss_3
# [wuunet_224_n3_fs_jaccard_best_pretrained test, threshold = 1.1300000000000001]:
# MULTICLASS DICE [val = 0.8782336115837097, std = 0.08847545087337494] JACCARD [val = 0.8015877604484558, std = 0.11226319521665573]
# BINARY DICE [val = 0.9528077840805054, std = 0.040170419961214066] JACCARD [val = 0.9124884605407715, std = 0.06850983947515488]
#
# test gauss_4
# [unet_224_n3_fs_jaccard_best_pretrained test, threshold = 0.79]:
# MULTICLASS DICE [val = 0.8668054938316345, std = 0.10059484094381332] JACCARD [val = 0.7914467453956604, std = 0.11455921828746796]
# BINARY DICE [val = 0.9209809303283691, std = 0.1652948260307312] JACCARD [val = 0.8795028328895569, std = 0.17039844393730164]
#
# test gauss_4
# [uunet_224_n3_fs_jaccard_best_pretrained test, threshold = 0.79]:
# MULTICLASS DICE [val = 0.8746188879013062, std = 0.09370695054531097] JACCARD [val = 0.7990587949752808, std = 0.11125820875167847]
# BINARY DICE [val = 0.9375492930412292, std = 0.12337737530469894] JACCARD [val = 0.8980673551559448, std = 0.13007813692092896]
#
# test gauss_4
# [wuunet_224_n3_fs_jaccard_best_pretrained test, threshold = 0.85]:
# MULTICLASS DICE [val = 0.8783736824989319, std = 0.08981912583112717] JACCARD [val = 0.801946759223938, std = 0.11292064189910889]
# BINARY DICE [val = 0.9532919526100159, std = 0.039992716163396835] JACCARD [val = 0.9133455753326416, std = 0.06809243559837341]
#
# test gauss_5
# [unet_224_n3_fs_jaccard_best_pretrained test, threshold = 0.55]:
# MULTICLASS DICE [val = 0.8666349649429321, std = 0.10018978267908096] JACCARD [val = 0.7911068797111511, std = 0.11426079273223877]
# BINARY DICE [val = 0.9206613898277283, std = 0.16512666642665863] JACCARD [val = 0.8789201974868774, std = 0.17026782035827637]
#
# test gauss_5
# [uunet_224_n3_fs_jaccard_best_pretrained test, threshold = 0.49]:
# MULTICLASS DICE [val = 0.8745838403701782, std = 0.09361454844474792] JACCARD [val = 0.7989258766174316, std = 0.11110265552997589]
# BINARY DICE [val = 0.9377581477165222, std = 0.12335178256034851] JACCARD [val = 0.8984110355377197, std = 0.1298566311597824]
#
# test gauss_5
# [wuunet_224_n3_fs_jaccard_best_pretrained test, threshold = 0.64]:
# MULTICLASS DICE [val = 0.8784008622169495, std = 0.08820740878582001] JACCARD [val = 0.8018059134483337, std = 0.11202439665794373]
# BINARY DICE [val = 0.9522857666015625, std = 0.041036926209926605] JACCARD [val = 0.9116411209106445, std = 0.06977461278438568]
#
# test gauss_6
# [unet_224_n3_fs_jaccard_best_pretrained test, threshold = 0.23]:
# MULTICLASS DICE [val = 0.8656076788902283, std = 0.10708476603031158] JACCARD [val = 0.7902324795722961, std = 0.1193789541721344]
# BINARY DICE [val = 0.9221000671386719, std = 0.16568642854690552] JACCARD [val = 0.8814132213592529, std = 0.1701425164937973]
#
# test gauss_6
# [uunet_224_n3_fs_jaccard_best_pretrained test, threshold = 0.33]:
# MULTICLASS DICE [val = 0.8740944266319275, std = 0.09393931180238724] JACCARD [val = 0.7981863617897034, std = 0.11170817166566849]
# BINARY DICE [val = 0.9371552467346191, std = 0.12340573221445084] JACCARD [val = 0.8973592519760132, std = 0.1300775110721588]
#
# test gauss_6
# [wuunet_224_n3_fs_jaccard_best_pretrained test, threshold = 0.34]:
# MULTICLASS DICE [val = 0.876707911491394, std = 0.09479078650474548] JACCARD [val = 0.7999488711357117, std = 0.11644472181797028]
# BINARY DICE [val = 0.9531093835830688, std = 0.04007560387253761] JACCARD [val = 0.9130188822746277, std = 0.06815080344676971]
#
# test nonint
# [unet_224_n3_fs_jaccard_best_pretrained test, threshold = 0.33]:
# MULTICLASS DICE [val = 0.859835684299469, std = 0.11047952622175217] JACCARD [val = 0.7825764417648315, std = 0.12082293629646301]
# BINARY DICE [val = 0.9155084490776062, std = 0.18036378920078278] JACCARD [val = 0.8743144273757935, std = 0.18298421800136566]
#
# test nonint
# [uunet_224_n3_fs_jaccard_best_pretrained test, threshold = 0.52]:
# MULTICLASS DICE [val = 0.8604017496109009, std = 0.10032208263874054] JACCARD [val = 0.7830035090446472, std = 0.11137774586677551]
# BINARY DICE [val = 0.904484212398529, std = 0.2026788294315338] JACCARD [val = 0.863013505935669, std = 0.2023286670446396]
#
# test nonint
# [wuunet_224_n3_fs_jaccard_best_pretrained test, threshold = 0.64]:
# MULTICLASS DICE [val = 0.8703920245170593, std = 0.09631896764039993] JACCARD [val = 0.7919505834579468, std = 0.11597663164138794]
# BINARY DICE [val = 0.940881073474884, std = 0.1033780500292778] JACCARD [val = 0.8998925089836121, std = 0.11452516168355942]
#
# test var_step
# [unet_224_n3_fs_jaccard_best_pretrained test, threshold = 0.52]:
# MULTICLASS DICE [val = 0.8675350546836853, std = 0.09710581600666046] JACCARD [val = 0.7923960089683533, std = 0.11164593696594238]
# BINARY DICE [val = 0.9221016764640808, std = 0.1653280109167099] JACCARD [val = 0.8814451694488525, std = 0.17035885155200958]
#
# test var_step
# [uunet_224_n3_fs_jaccard_best_pretrained test, threshold = 0.73]:
# MULTICLASS DICE [val = 0.8742293119430542, std = 0.09361961483955383] JACCARD [val = 0.7986941933631897, std = 0.11198551952838898]
# BINARY DICE [val = 0.9350395798683167, std = 0.12337511777877808] JACCARD [val = 0.8936268091201782, std = 0.13060393929481506]
#
# test var_step
# [wuunet_224_n3_fs_jaccard_best_pretrained test, threshold = 0.68]:
# MULTICLASS DICE [val = 0.8806811571121216, std = 0.08266422152519226] JACCARD [val = 0.8047024011611938, std = 0.10689722001552582]
# BINARY DICE [val = 0.9547039270401001, std = 0.03806907311081886] JACCARD [val = 0.9157037138938904, std = 0.06524180620908737]
#
# test add
# [unet_224_n3_fs_jaccard_best_pretrained test, threshold = 0.91]:
# MULTICLASS DICE [val = 0.8629375100135803, std = 0.11035966128110886] JACCARD [val = 0.7872307300567627, std = 0.12051474303007126]
# BINARY DICE [val = 0.915651798248291, std = 0.1801297962665558] JACCARD [val = 0.8746541142463684, std = 0.1829230934381485]
#
# test add
# [uunet_224_n3_fs_jaccard_best_pretrained test, threshold = 0.9400000000000001]:
# MULTICLASS DICE [val = 0.8635686635971069, std = 0.09900359809398651] JACCARD [val = 0.7872214913368225, std = 0.10813993960618973]
# BINARY DICE [val = 0.9058951139450073, std = 0.2013583779335022] JACCARD [val = 0.8649479746818542, std = 0.19981813430786133]
#
# test add
# [wuunet_224_n3_fs_jaccard_best_pretrained test, threshold = 0.96]:
# MULTICLASS DICE [val = 0.8709046244621277, std = 0.10116321593523026] JACCARD [val = 0.7931992411613464, std = 0.11842259019613266]
# BINARY DICE [val = 0.941645085811615, std = 0.09769825637340546] JACCARD [val = 0.9003621339797974, std = 0.10725566744804382]
#
# test add_weight
# [unet_224_n3_fs_jaccard_best_pretrained test, threshold = 1.53]:
# MULTICLASS DICE [val = 0.8630505800247192, std = 0.11043859273195267] JACCARD [val = 0.7875046730041504, std = 0.12102582305669785]
# BINARY DICE [val = 0.9157057404518127, std = 0.18079280853271484] JACCARD [val = 0.8749482035636902, std = 0.18405388295650482]
#
# test add_weight
# [uunet_224_n3_fs_jaccard_best_pretrained test, threshold = 2.0100000000000002]:
# MULTICLASS DICE [val = 0.8706000447273254, std = 0.09421264380216599] JACCARD [val = 0.792904794216156, std = 0.11295896023511887]
# BINARY DICE [val = 0.9331846237182617, std = 0.12253173440694809] JACCARD [val = 0.890234112739563, std = 0.13022086024284363]
#
# test add_weight
# [wuunet_224_n3_fs_jaccard_best_pretrained test, threshold = 1.9100000000000001]:
# MULTICLASS DICE [val = 0.8745286464691162, std = 0.09504565596580505] JACCARD [val = 0.7974212765693665, std = 0.11556767672300339]
# BINARY DICE [val = 0.9471058249473572, std = 0.0822804719209671] JACCARD [val = 0.9067918658256531, std = 0.0963485911488533]

# %% [markdown]
# # Fullsize 224x224 Gauss dichotomy

# %%
ML_MODELS = [
    'unet_224_n3_fs_jaccard',
    'uunet_224_n3_fs_jaccard',
    'wuunet_224_n3_fs_jaccard'
]

INPUT_SIZE = (224, 224)

DATASET_VARIANTS = ['test']  #['train_test']

COMBINATION_TYPES = ['gauss_0']
print(COMBINATION_TYPES)

VARIANTS = {
    'unet_224_n3_fs_jaccard':   ['pretrained'],  #['mult_trainval_acc', 'loss']
    'uunet_224_n3_fs_jaccard':  ['pretrained'],  #['mult_acc', 'mult_loss', 'mult_trainval_acc']
    'wuunet_224_n3_fs_jaccard': ['pretrained']   #['mult_acc', 'mult_loss', 'mult_trainval_acc']
}

for dataset_variant in DATASET_VARIANTS:
    for comb_type in COMBINATION_TYPES:
        for ml_model_name in ML_MODELS:
            print(dataset_variant, comb_type)
            validation = Validation(dataset_variant, comb_type, input_size=INPUT_SIZE)
            for snapshot_variant in VARIANTS[ml_model_name]:
                validation.gauss_dichotomy(ml_model_name, snapshot_variant)
# Out:
# ['gauss_0']
# test gauss_0
# is_448_complex = False, self.division_coeff = 2
# dataloader length = 2580
# unet
# Successfully loaded pretrained weights from "pretrained/unet_224_n3_fs_jaccard/snapshots/pretrained.pth.tar"
# Dichotomy result: [unet_224_n3_fs_jaccard_pretrained test, threshold = 0.7599999904632568, gauss_div = 4.074999809265137]:
# MULTICLASS DICE [val = 0.8668707609176636, std = 0.10050082951784134] JACCARD [val = 0.7915051579475403, std = 0.11447949707508087]
# BINARY DICE [val = 0.9210439324378967, std = 0.16530349850654602] JACCARD [val = 0.8796152472496033, std = 0.1704064905643463]
#
# test gauss_0
# is_448_complex = False, self.division_coeff = 2
# dataloader length = 2580
# uunet
# Successfully loaded pretrained weights from "pretrained/uunet_224_n3_fs_jaccard/snapshots/pretrained.pth.tar"
# Dichotomy result: [uunet_224_n3_fs_jaccard_pretrained test, threshold = 0.7200000286102295, gauss_div = 4.199461460113525]:
# MULTICLASS DICE [val = 0.8746772408485413, std = 0.0936877503991127] JACCARD [val = 0.799129068851471, std = 0.1111936941742897]
# BINARY DICE [val = 0.937656819820404, std = 0.12336412072181702] JACCARD [val = 0.8982473015785217, std = 0.1299886703491211]
#
# test gauss_0
# is_448_complex = False, self.division_coeff = 2
# dataloader length = 2580
# wuunet
# Successfully loaded pretrained weights from "pretrained/wuunet_224_n3_fs_jaccard/snapshots/pretrained.pth.tar"
# Dichotomy result: [wuunet_224_n3_fs_jaccard_pretrained test, threshold = 0.8999999761581421, gauss_div = 3.7955079078674316]:
# MULTICLASS DICE [val = 0.8787474632263184, std = 0.08796214312314987] JACCARD [val = 0.8023524880409241, std = 0.11148250848054886]
# BINARY DICE [val = 0.9533822536468506, std = 0.039862070232629776] JACCARD [val = 0.9134946465492249, std = 0.0678955540060997]

# %% [markdown]
# # Fullsize 224x224 Gauss dichotomy (train_test)

# %%
ML_MODELS = [
    'unet_224_n3_fs_jaccard',
    'uunet_224_n3_fs_jaccard',
    'wuunet_224_n3_fs_jaccard'
]

INPUT_SIZE = (224, 224)

DATASET_VARIANTS = ['train_test']

COMBINATION_TYPES = ['gauss_0']
print(COMBINATION_TYPES)

VARIANTS = {
    'unet_224_n3_fs_jaccard':   ['pretrained'],  #['mult_trainval_acc', 'loss']
    'uunet_224_n3_fs_jaccard':  ['pretrained'],  #['mult_acc', 'mult_loss', 'mult_trainval_acc']
    'wuunet_224_n3_fs_jaccard': ['pretrained']   #['mult_acc', 'mult_loss', 'mult_trainval_acc']
}

for dataset_variant in DATASET_VARIANTS:
    for comb_type in COMBINATION_TYPES:
        for ml_model_name in ML_MODELS:
            print(dataset_variant, comb_type)
            validation = Validation(dataset_variant, comb_type, input_size=INPUT_SIZE)
            for snapshot_variant in VARIANTS[ml_model_name]:
                validation.gauss_dichotomy(ml_model_name, snapshot_variant)
# Out:
# ['gauss_0']
# train_test gauss_0
# is_448_complex = False, self.division_coeff = 2
# dataloader length = 6250
# unet
# Successfully loaded pretrained weights from "pretrained/unet_224_n3_fs_jaccard/snapshots/pretrained.pth.tar"
# Dichotomy result: [unet_224_n3_fs_jaccard_pretrained train_test, threshold = 0.7699999809265137, gauss_div = 4.107995510101318]:
# MULTICLASS DICE [val = 0.8844870328903198, std = 0.09509827941656113] JACCARD [val = 0.8187053203582764, std = 0.12168067693710327]
# BINARY DICE [val = 0.9323733448982239, std = 0.12094240635633469] JACCARD [val = 0.8904637098312378, std = 0.13264742493629456]
#
# train_test gauss_0
# is_448_complex = False, self.division_coeff = 2
# dataloader length = 6250
# uunet
# Successfully loaded pretrained weights from "pretrained/uunet_224_n3_fs_jaccard/snapshots/pretrained.pth.tar"
# Dichotomy result: [uunet_224_n3_fs_jaccard_pretrained train_test, threshold = 0.7599999904632568, gauss_div = 4.168528079986572]:
# MULTICLASS DICE [val = 0.8781429529190063, std = 0.10405126214027405] JACCARD [val = 0.8108188509941101, std = 0.13245736062526703]
# BINARY DICE [val = 0.9374496340751648, std = 0.09912828356027603] JACCARD [val = 0.8953897953033447, std = 0.11503203958272934]
#
# train_test gauss_0
# is_448_complex = False, self.division_coeff = 2
# dataloader length = 6250
# wuunet
# Successfully loaded pretrained weights from "pretrained/wuunet_224_n3_fs_jaccard/snapshots/pretrained.pth.tar"
# Dichotomy result: [wuunet_224_n3_fs_jaccard_pretrained train_test, threshold = 0.9700000286102295, gauss_div = 3.9358603954315186]:
# MULTICLASS DICE [val = 0.8812807202339172, std = 0.09987156838178635] JACCARD [val = 0.8140133619308472, std = 0.13009941577911377]
# BINARY DICE [val = 0.9434291124343872, std = 0.0647827535867691] JACCARD [val = 0.9006697535514832, std = 0.09049783647060394]
