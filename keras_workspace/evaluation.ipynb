# %%
import numpy as np

from keras_unet_models import wuunet, unet
from keras_utils import jaccard_acc, bin_jaccard_acc, bce_jaccard_loss, bce_bin_jaccard_loss
from keras_dataset import Dataset, augm_train, augm_val
from keras_validation import Validation

from tensorflow.python.client import device_lib

import json

print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 6614445994182473656
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 7416424704
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 7161694883038686479
# physical_device_desc: "device: 0, name: GeForce RTX 2070, pci bus id: 0000:1c:00.0, compute capability: 7.5"
# ]

# %%
# %matplotlib inline
np.set_printoptions(precision=49)

# %%
import os

def get_snapshots(ml_model_name):
    all_snapshots = os.listdir('output/keras/' + ml_model_name + '/snapshots')
    snapshots_map = {
        int(snapshot[snapshot.rfind('_') + 1 : snapshot.rfind('.')]) : snapshot 
        for snapshot in all_snapshots
    }
    return snapshots_map.values()

# %%
def evaluate():
    test_model_metrics = {}
    for dataset_variant in DATASET_VARIANTS:
        for ml_model_name in ML_MODELS:
            print('================================================')
            print(ml_model_name)
            jb_mean_max, jb_mean_max_thr, jb_mean_max_model = 0.0, 0.0, ''
            jb_std_min,  jb_std_min_thr,  jb_std_min_model  = 1.0, 0.0, ''
            jm_mean_max, jm_mean_max_thr, jm_mean_max_model = 0.0, 0.0, ''
            jm_std_min,  jm_std_min_thr,  jm_std_min_model  = 1.0, 0.0, ''
            validation = Validation(dataset_variant)
            snapshots = get_snapshots(ml_model_name)
            for i, snapshot_variant in enumerate(snapshots):
                print('-----------------------------------------------')
                print('{}/{}'.format(i, len(snapshots)))
                print(ml_model_name + ": " + snapshot_variant)
                model_full_name = ml_model_name + '_' + snapshot_variant
                thr, jm_mean, jm_std, jb_mean, jb_std = validation.calculate_thresholds(
                    ml_model_name, snapshot_variant
                )
                test_model_metrics[model_full_name] = (thr, jm_mean, jm_std, jb_mean, jb_std)
                if (jb_mean_max < jb_mean):
                    jb_mean_max = jb_mean
                    jb_mean_max_thr = thr
                    jb_mean_max_model = model_full_name
                if (jb_std_min > jb_std):
                    jb_std_min = jb_std
                    jb_std_min_thr = thr
                    jb_std_min_model = model_full_name
                if (jm_mean_max < jm_mean):
                    jm_mean_max = jm_mean
                    jm_mean_max_thr = thr
                    jm_mean_max_model = model_full_name
                if (jm_std_min > jm_std):
                    jm_std_min = jm_std
                    jm_std_min_thr = thr
                    jm_std_min_model = model_full_name
            #validation.draw_barchart(test_model_metrics)
            print('================================================')
            print('SUMMARY:')
            print('Jaccard bin  mean max: name = {}, value = {}, thr = {}'.format(jb_mean_max_model, jb_mean_max, jb_mean_max_thr))
            print('Jaccard bin  std min:  name = {}, value = {}, thr = {}'.format(jb_std_min_model,  jb_std_min, jb_std_min_thr))
            print('Jaccard mult mean max: name = {}, value = {}, thr = {}'.format(jm_mean_max_model, jm_mean_max, jm_mean_max_thr))
            print('Jaccard mult std min:  name = {}, value = {}, thr = {}'.format(jm_std_min_model,  jm_std_min, jm_std_min_thr))
            print('================================================')

        test_model_metrics_json = {
            key: [str(test_model_metrics[key][0]), str(test_model_metrics[key][1]), str(test_model_metrics[key][2]), 
                  str(test_model_metrics[key][3]), str(test_model_metrics[key][4])]
            for key in test_model_metrics
        }

        json.dump(test_model_metrics_json, 
                  open('output/evaluation/ow_224/{}_validation_metrics.json'.format(dataset_variant), 'w'))

# %%
ML_MODELS = [
    'unet_224_ow',
    'wuunet_224_ow',
    'wuunet_light_224_ow'
]


INPUT_SIZE = (224, 224)

DATASET_VARIANTS = ['test']  #['train_test']

COMBINATION_TYPES = ['nonint']
print(COMBINATION_TYPES)

evaluate()
# Out:
# ['nonint']
# ================================================
# unet_224_ow
# -----------------------------------------------
# 0/54
# unet_224_ow: best_val_loss_51.hdf5
# [unet_224_ow_best_val_loss_51.hdf5, threshold = 0.27]:
# MULTICLASS JACCARD [val = 0.8227515816688538, std = 0.10845281928777695]
# BINARY JACCARD [val = 0.8654728531837463, std = 0.09086626023054123]
#
# -----------------------------------------------
# 1/54
# unet_224_ow: best_val_acc_60.hdf5
# [unet_224_ow_best_val_acc_60.hdf5, threshold = 0.22]:
# MULTICLASS JACCARD [val = 0.8208708763122559, std = 0.11016514897346497]
# BINARY JACCARD [val = 0.8616129159927368, std = 0.09434057772159576]
#
# -----------------------------------------------
# 2/54
# unet_224_ow: best_val_acc_11.hdf5
# [unet_224_ow_best_val_acc_11.hdf5, threshold = 0.96]:
# MULTICLASS JACCARD [val = 0.6780094504356384, std = 0.1659507155418396]
# BINARY JACCARD [val = 0.7059192061424255, std = 0.15229350328445435]
#
# -----------------------------------------------
# 3/54
# unet_224_ow: best_val_acc_343.hdf5
# [unet_224_ow_best_val_acc_343.hdf5, threshold = 0.54]:
# MULTICLASS JACCARD [val = 0.8675811886787415, std = 0.09480717778205872]
# BINARY JACCARD [val = 0.9061018228530884, std = 0.0766492411494255]
#
# -----------------------------------------------
# 4/54
# unet_224_ow: best_val_loss_337.hdf5
# [unet_224_ow_best_val_loss_337.hdf5, threshold = 0.6]:
# MULTICLASS JACCARD [val = 0.8668115139007568, std = 0.09481679648160934]
# BINARY JACCARD [val = 0.9055373668670654, std = 0.07636860013008118]
#
# -----------------------------------------------
# 5/54
# unet_224_ow: best_val_acc_299.hdf5
# [unet_224_ow_best_val_acc_299.hdf5, threshold = 0.67]:
# MULTICLASS JACCARD [val = 0.862694501876831, std = 0.09100649505853653]
# BINARY JACCARD [val = 0.901185154914856, std = 0.0733458623290062]
#
# -----------------------------------------------
# 6/54
# unet_224_ow: best_val_loss_306.hdf5
# [unet_224_ow_best_val_loss_306.hdf5, threshold = 0.52]:
# MULTICLASS JACCARD [val = 0.8634442090988159, std = 0.09169323742389679]
# BINARY JACCARD [val = 0.903569757938385, std = 0.07276524603366852]
#
# -----------------------------------------------
# 7/54
# unet_224_ow: best_val_acc_52.hdf5
# [unet_224_ow_best_val_acc_52.hdf5, threshold = 0.36]:
# MULTICLASS JACCARD [val = 0.823314905166626, std = 0.10749129205942154]
# BINARY JACCARD [val = 0.8654076457023621, std = 0.08995946496725082]
#
# -----------------------------------------------
# 8/54
# unet_224_ow: best_val_acc_310.hdf5
# [unet_224_ow_best_val_acc_310.hdf5, threshold = 0.62]:
# MULTICLASS JACCARD [val = 0.8667504787445068, std = 0.08954321593046188]
# BINARY JACCARD [val = 0.9056167602539062, std = 0.07082053273916245]
#
# -----------------------------------------------
# 9/54
# unet_224_ow: best_val_loss_17.hdf5
# [unet_224_ow_best_val_loss_17.hdf5, threshold = 0.07]:
# MULTICLASS JACCARD [val = 0.6898977756500244, std = 0.17147918045520782]
# BINARY JACCARD [val = 0.7188582420349121, std = 0.16149327158927917]
#
# -----------------------------------------------
# 10/54
# unet_224_ow: best_val_loss_20.hdf5
# [unet_224_ow_best_val_loss_20.hdf5, threshold = 0.97]:
# MULTICLASS JACCARD [val = 0.7141387462615967, std = 0.1431027501821518]
# BINARY JACCARD [val = 0.7357401251792908, std = 0.13212287425994873]
#
# -----------------------------------------------
# 11/54
# unet_224_ow: best_val_loss_273.hdf5
# [unet_224_ow_best_val_loss_273.hdf5, threshold = 0.93]:
# MULTICLASS JACCARD [val = 0.8476555347442627, std = 0.09679319709539413]
# BINARY JACCARD [val = 0.8862735629081726, std = 0.08253133296966553]
#
# -----------------------------------------------
# 12/54
# unet_224_ow: best_val_loss_40.hdf5
# [unet_224_ow_best_val_loss_40.hdf5, threshold = 0.92]:
# MULTICLASS JACCARD [val = 0.7870888113975525, std = 0.12372905015945435]
# BINARY JACCARD [val = 0.8325122594833374, std = 0.10716933757066727]
#
# -----------------------------------------------
# 13/54
# unet_224_ow: best_val_loss_2.hdf5
# [unet_224_ow_best_val_loss_2.hdf5, threshold = 0.01]:
# MULTICLASS JACCARD [val = 0.5804886817932129, std = 0.18519683182239532]
# BINARY JACCARD [val = 0.5888091921806335, std = 0.17951585352420807]
#
# -----------------------------------------------
# 14/54
# unet_224_ow: best_val_acc_272.hdf5
# [unet_224_ow_best_val_acc_272.hdf5, threshold = 0.54]:
# MULTICLASS JACCARD [val = 0.8264867067337036, std = 0.10822945833206177]
# BINARY JACCARD [val = 0.8672620058059692, std = 0.0981600284576416]
#
# -----------------------------------------------
# 15/54
# unet_224_ow: best_val_loss_70.hdf5
# [unet_224_ow_best_val_loss_70.hdf5, threshold = 0.39]:
# MULTICLASS JACCARD [val = 0.8316534161567688, std = 0.10295499861240387]
# BINARY JACCARD [val = 0.8723098635673523, std = 0.08802583813667297]
#
# -----------------------------------------------
# 16/54
# unet_224_ow: best_val_loss_3.hdf5
# [unet_224_ow_best_val_loss_3.hdf5, threshold = 0.59]:
# MULTICLASS JACCARD [val = 0.6180086135864258, std = 0.17175422608852386]
# BINARY JACCARD [val = 0.6281482577323914, std = 0.16590291261672974]
#
# -----------------------------------------------
# 17/54
# unet_224_ow: best_val_loss_29.hdf5
# [unet_224_ow_best_val_loss_29.hdf5, threshold = 0.49]:
# MULTICLASS JACCARD [val = 0.7546517252922058, std = 0.14080916345119476]
# BINARY JACCARD [val = 0.8057853579521179, std = 0.12051430344581604]
#
# -----------------------------------------------
# 18/54
# unet_224_ow: best_val_acc_10.hdf5
# [unet_224_ow_best_val_acc_10.hdf5, threshold = 0.98]:
# MULTICLASS JACCARD [val = 0.6797987222671509, std = 0.15531954169273376]
# BINARY JACCARD [val = 0.7053787112236023, std = 0.14272798597812653]
#
# -----------------------------------------------
# 19/54
# unet_224_ow: best_val_acc_28.hdf5
# [unet_224_ow_best_val_acc_28.hdf5, threshold = 0.89]:
# MULTICLASS JACCARD [val = 0.7551948428153992, std = 0.1466103196144104]
# BINARY JACCARD [val = 0.8177119493484497, std = 0.12748900055885315]
#
# -----------------------------------------------
# 20/54
# unet_224_ow: best_val_loss_30.hdf5
# [unet_224_ow_best_val_loss_30.hdf5, threshold = 0.45]:
# MULTICLASS JACCARD [val = 0.7645761370658875, std = 0.13590794801712036]
# BINARY JACCARD [val = 0.8104135394096375, std = 0.12245915830135345]
#
# -----------------------------------------------
# 21/54
# unet_224_ow: best_val_acc_1.hdf5
# [unet_224_ow_best_val_acc_1.hdf5, threshold = 0.4]:
# MULTICLASS JACCARD [val = 0.5653433799743652, std = 0.20911423861980438]
# BINARY JACCARD [val = 0.5653433799743652, std = 0.20911423861980438]
#
# -----------------------------------------------
# 22/54
# unet_224_ow: best_val_acc_21.hdf5
# [unet_224_ow_best_val_acc_21.hdf5, threshold = 0.39]:
# MULTICLASS JACCARD [val = 0.7184846997261047, std = 0.170169398188591]
# BINARY JACCARD [val = 0.7626914978027344, std = 0.15620779991149902]
#
# -----------------------------------------------
# 23/54
# unet_224_ow: best_val_acc_443.hdf5
# [unet_224_ow_best_val_acc_443.hdf5, threshold = 0.62]:
# MULTICLASS JACCARD [val = 0.8667029738426208, std = 0.0968933030962944]
# BINARY JACCARD [val = 0.9051606059074402, std = 0.07848148792982101]
#
# -----------------------------------------------
# 24/54
# unet_224_ow: best_val_loss_26.hdf5
# [unet_224_ow_best_val_loss_26.hdf5, threshold = 0.5]:
# MULTICLASS JACCARD [val = 0.7525832653045654, std = 0.15281003713607788]
# BINARY JACCARD [val = 0.7930638790130615, std = 0.13443714380264282]
#
# -----------------------------------------------
# 25/54
# unet_224_ow: best_val_acc_45.hdf5
# [unet_224_ow_best_val_acc_45.hdf5, threshold = 0.54]:
# MULTICLASS JACCARD [val = 0.7901013493537903, std = 0.12516209483146667]
# BINARY JACCARD [val = 0.8340186476707458, std = 0.11511097103357315]
#
# -----------------------------------------------
# 26/54
# unet_224_ow: best_val_loss_117.hdf5
# [unet_224_ow_best_val_loss_117.hdf5, threshold = 0.33]:
# MULTICLASS JACCARD [val = 0.8376070857048035, std = 0.10172169655561447]
# BINARY JACCARD [val = 0.8776745200157166, std = 0.0860188752412796]
#
# -----------------------------------------------
# 27/54
# unet_224_ow: best_val_loss_44.hdf5
# [unet_224_ow_best_val_loss_44.hdf5, threshold = 0.39]:
# MULTICLASS JACCARD [val = 0.7844923138618469, std = 0.134351447224617]
# BINARY JACCARD [val = 0.8291453123092651, std = 0.12408626824617386]
#
# -----------------------------------------------
# 28/54
# unet_224_ow: best_val_loss_277.hdf5
# [unet_224_ow_best_val_loss_277.hdf5, threshold = 0.61]:
# MULTICLASS JACCARD [val = 0.8584175705909729, std = 0.08842450380325317]
# BINARY JACCARD [val = 0.8985989689826965, std = 0.0702524185180664]
#
# -----------------------------------------------
# 29/54
# unet_224_ow: best_val_loss_55.hdf5
# [unet_224_ow_best_val_loss_55.hdf5, threshold = 0.37]:
# MULTICLASS JACCARD [val = 0.8226392865180969, std = 0.1090671494603157]
# BINARY JACCARD [val = 0.8641669750213623, std = 0.09176243841648102]
#
# -----------------------------------------------
# 30/54
# unet_224_ow: best_val_acc_48.hdf5
# [unet_224_ow_best_val_acc_48.hdf5, threshold = 0.74]:
# MULTICLASS JACCARD [val = 0.804316520690918, std = 0.12051623314619064]
# BINARY JACCARD [val = 0.844714343547821, std = 0.11098494380712509]
#
# -----------------------------------------------
# 31/54
# unet_224_ow: best_val_loss_90.hdf5
# [unet_224_ow_best_val_loss_90.hdf5, threshold = 0.64]:
# MULTICLASS JACCARD [val = 0.8406384587287903, std = 0.09461009502410889]
# BINARY JACCARD [val = 0.8799890279769897, std = 0.07964973151683807]
#
# -----------------------------------------------
# 32/54
# unet_224_ow: best_val_acc_304.hdf5
# [unet_224_ow_best_val_acc_304.hdf5, threshold = 0.71]:
# MULTICLASS JACCARD [val = 0.8663952946662903, std = 0.08558458834886551]
# BINARY JACCARD [val = 0.9049580693244934, std = 0.06688519567251205]
#
# -----------------------------------------------
# 33/54
# unet_224_ow: best_val_acc_19.hdf5
# [unet_224_ow_best_val_acc_19.hdf5, threshold = 0.91]:
# MULTICLASS JACCARD [val = 0.7034134268760681, std = 0.15899553894996643]
# BINARY JACCARD [val = 0.7447963356971741, std = 0.14440001547336578]
#
# -----------------------------------------------
# 34/54
# unet_224_ow: best_val_loss_27.hdf5
# [unet_224_ow_best_val_loss_27.hdf5, threshold = 0.14]:
# MULTICLASS JACCARD [val = 0.7432689070701599, std = 0.15806636214256287]
# BINARY JACCARD [val = 0.7924907803535461, std = 0.1407572478055954]
#
# -----------------------------------------------
# 35/54
# unet_224_ow: best_val_acc_15.hdf5
# [unet_224_ow_best_val_acc_15.hdf5, threshold = 0.8200000000000001]:
# MULTICLASS JACCARD [val = 0.6894832253456116, std = 0.1567866951227188]
# BINARY JACCARD [val = 0.705775260925293, std = 0.14682142436504364]
#
# -----------------------------------------------
# 36/54
# unet_224_ow: best_val_acc_142.hdf5
# [unet_224_ow_best_val_acc_142.hdf5, threshold = 0.3]:
# MULTICLASS JACCARD [val = 0.8381118774414062, std = 0.10198945552110672]
# BINARY JACCARD [val = 0.8784633278846741, std = 0.08690003305673599]
#
# -----------------------------------------------
# 37/54
# unet_224_ow: best_val_acc_87.hdf5
# [unet_224_ow_best_val_acc_87.hdf5, threshold = 0.25]:
# MULTICLASS JACCARD [val = 0.8363242149353027, std = 0.10060106217861176]
# BINARY JACCARD [val = 0.8770036101341248, std = 0.08512558788061142]
#
# -----------------------------------------------
# 38/54
# unet_224_ow: best_val_acc_269.hdf5
# [unet_224_ow_best_val_acc_269.hdf5, threshold = 0.85]:
# MULTICLASS JACCARD [val = 0.8372032642364502, std = 0.10179155319929123]
# BINARY JACCARD [val = 0.8797236680984497, std = 0.08466748148202896]
#
# -----------------------------------------------
# 39/54
# unet_224_ow: best_val_acc_276.hdf5
# [unet_224_ow_best_val_acc_276.hdf5, threshold = 0.68]:
# MULTICLASS JACCARD [val = 0.8542980551719666, std = 0.09176117926836014]
# BINARY JACCARD [val = 0.8939773440361023, std = 0.07469861954450607]
#
# -----------------------------------------------
# 40/54
# unet_224_ow: best_val_acc_282.hdf5
# [unet_224_ow_best_val_acc_282.hdf5, threshold = 0.39]:
# MULTICLASS JACCARD [val = 0.8511176705360413, std = 0.09626847505569458]
# BINARY JACCARD [val = 0.8922489881515503, std = 0.07629742473363876]
#
# -----------------------------------------------
# 41/54
# unet_224_ow: best_val_acc_789.hdf5
# [unet_224_ow_best_val_acc_789.hdf5, threshold = 0.55]:
# MULTICLASS JACCARD [val = 0.870606005191803, std = 0.09089922159910202]
# BINARY JACCARD [val = 0.907997190952301, std = 0.07148385792970657]
#
# -----------------------------------------------
# 42/54
# unet_224_ow: best_val_acc_41.hdf5
# [unet_224_ow_best_val_acc_41.hdf5, threshold = 0.8]:
# MULTICLASS JACCARD [val = 0.7997235059738159, std = 0.11904740333557129]
# BINARY JACCARD [val = 0.8410220742225647, std = 0.10330722481012344]
#
# -----------------------------------------------
# 43/54
# unet_224_ow: best_val_acc_436.hdf5
# [unet_224_ow_best_val_acc_436.hdf5, threshold = 0.64]:
# MULTICLASS JACCARD [val = 0.8667536973953247, std = 0.09682118892669678]
# BINARY JACCARD [val = 0.9051690101623535, std = 0.0784199982881546]
#
# -----------------------------------------------
# 44/54
# unet_224_ow: best_val_loss_79.hdf5
# [unet_224_ow_best_val_loss_79.hdf5, threshold = 0.25]:
# MULTICLASS JACCARD [val = 0.8328365683555603, std = 0.10057417303323746]
# BINARY JACCARD [val = 0.8750074505805969, std = 0.0835968479514122]
#
# -----------------------------------------------
# 45/54
# unet_224_ow: best_val_acc_9.hdf5
# [unet_224_ow_best_val_acc_9.hdf5, threshold = 0.91]:
# MULTICLASS JACCARD [val = 0.6732023358345032, std = 0.1704384982585907]
# BINARY JACCARD [val = 0.6962284445762634, std = 0.15721997618675232]
#
# -----------------------------------------------
# 46/54
# unet_224_ow: best_val_acc_47.hdf5
# [unet_224_ow_best_val_acc_47.hdf5, threshold = 0.5]:
# MULTICLASS JACCARD [val = 0.7994914650917053, std = 0.12105375528335571]
# BINARY JACCARD [val = 0.8426094651222229, std = 0.10879336297512054]
#
# -----------------------------------------------
# 47/54
# unet_224_ow: best_val_acc_687.hdf5
# [unet_224_ow_best_val_acc_687.hdf5, threshold = 0.63]:
# MULTICLASS JACCARD [val = 0.862787127494812, std = 0.09746864438056946]
# BINARY JACCARD [val = 0.9008968472480774, std = 0.07929059118032455]
#
# -----------------------------------------------
# 48/54
# unet_224_ow: best_val_loss_94.hdf5
# [unet_224_ow_best_val_loss_94.hdf5, threshold = 0.37]:
# MULTICLASS JACCARD [val = 0.8400415182113647, std = 0.0974348708987236]
# BINARY JACCARD [val = 0.8802275657653809, std = 0.08156167715787888]
#
# -----------------------------------------------
# 49/54
# unet_224_ow: best_val_acc_8.hdf5
# [unet_224_ow_best_val_acc_8.hdf5, threshold = 0.37]:
# MULTICLASS JACCARD [val = 0.6621929407119751, std = 0.17127598822116852]
# BINARY JACCARD [val = 0.706117570400238, std = 0.15777279436588287]
#
# -----------------------------------------------
# 50/54
# unet_224_ow: best_val_acc_38.hdf5
# [unet_224_ow_best_val_acc_38.hdf5, threshold = 0.4]:
# MULTICLASS JACCARD [val = 0.7588472366333008, std = 0.1425369828939438]
# BINARY JACCARD [val = 0.8059316277503967, std = 0.13400419056415558]
#
# -----------------------------------------------
# 51/54
# unet_224_ow: best_val_loss_274.hdf5
# [unet_224_ow_best_val_loss_274.hdf5, threshold = 0.19]:
# MULTICLASS JACCARD [val = 0.8498848080635071, std = 0.09748616814613342]
# BINARY JACCARD [val = 0.8910098671913147, std = 0.08090103417634964]
#
# -----------------------------------------------
# 52/54
# unet_224_ow: best_val_loss_12.hdf5
# [unet_224_ow_best_val_loss_12.hdf5, threshold = 0.96]:
# MULTICLASS JACCARD [val = 0.7082020044326782, std = 0.14998449385166168]
# BINARY JACCARD [val = 0.7409197092056274, std = 0.13508406281471252]
#
# -----------------------------------------------
# 53/54
# unet_224_ow: best_val_loss_295.hdf5
# [unet_224_ow_best_val_loss_295.hdf5, threshold = 0.89]:
# MULTICLASS JACCARD [val = 0.8577221035957336, std = 0.09487470984458923]
# BINARY JACCARD [val = 0.8950986862182617, std = 0.07796748727560043]
#
# ================================================
# SUMMARY:
# Jaccard bin  mean max: name = unet_224_ow_best_val_acc_789.hdf5, value = 0.907997190952301, thr = 0.55
# Jaccard bin  std min:  name = unet_224_ow_best_val_acc_304.hdf5, value = 0.06688519567251205, thr = 0.71
# Jaccard mult mean max: name = unet_224_ow_best_val_acc_789.hdf5, value = 0.870606005191803, thr = 0.55
# Jaccard mult std min:  name = unet_224_ow_best_val_acc_304.hdf5, value = 0.08558458834886551, thr = 0.71
# ================================================
# ================================================
# wuunet_224_ow
# -----------------------------------------------
# 0/65
# wuunet_224_ow: best_val_mult_loss_543.hdf5
# [wuunet_224_ow_best_val_mult_loss_543.hdf5, threshold = 0.62]:
# MULTICLASS JACCARD [val = 0.8826791644096375, std = 0.07525437325239182]
# BINARY JACCARD [val = 0.9208341836929321, std = 0.05898584425449371]
#
# -----------------------------------------------
# 1/65
# wuunet_224_ow: best_val_mult_acc_353.hdf5
# [wuunet_224_ow_best_val_mult_acc_353.hdf5, threshold = 0.7000000000000001]:
# MULTICLASS JACCARD [val = 0.8642285466194153, std = 0.10337506234645844]
# BINARY JACCARD [val = 0.9030763506889343, std = 0.09566079080104828]
#
# -----------------------------------------------
# 2/65
# wuunet_224_ow: best_val_mult_acc_63.hdf5
# [wuunet_224_ow_best_val_mult_acc_63.hdf5, threshold = 0.49]:
# MULTICLASS JACCARD [val = 0.8560314774513245, std = 0.08809284120798111]
# BINARY JACCARD [val = 0.8981466889381409, std = 0.06916020065546036]
#
# -----------------------------------------------
# 3/65
# wuunet_224_ow: best_val_mult_acc_13.hdf5
# [wuunet_224_ow_best_val_mult_acc_13.hdf5, threshold = 0.6]:
# MULTICLASS JACCARD [val = 0.7122061252593994, std = 0.1630028337240219]
# BINARY JACCARD [val = 0.7764458060264587, std = 0.1336529403924942]
#
# -----------------------------------------------
# 4/65
# wuunet_224_ow: best_val_mult_loss_23.hdf5
# [wuunet_224_ow_best_val_mult_loss_23.hdf5, threshold = 0.07]:
# MULTICLASS JACCARD [val = 0.7680312991142273, std = 0.13782550394535065]
# BINARY JACCARD [val = 0.8515922427177429, std = 0.0902167335152626]
#
# -----------------------------------------------
# 5/65
# wuunet_224_ow: best_val_bin_acc_56.hdf5
# [wuunet_224_ow_best_val_bin_acc_56.hdf5, threshold = 0.78]:
# MULTICLASS JACCARD [val = 0.8367372751235962, std = 0.10339003801345825]
# BINARY JACCARD [val = 0.8764059543609619, std = 0.08970008045434952]
#
# -----------------------------------------------
# 6/65
# wuunet_224_ow: best_val_mult_acc_47.hdf5
# [wuunet_224_ow_best_val_mult_acc_47.hdf5, threshold = 0.88]:
# MULTICLASS JACCARD [val = 0.8105376362800598, std = 0.1349318027496338]
# BINARY JACCARD [val = 0.8563740849494934, std = 0.1229759007692337]
#
# -----------------------------------------------
# 7/65
# wuunet_224_ow: best_val_bin_acc_123.hdf5
# [wuunet_224_ow_best_val_bin_acc_123.hdf5, threshold = 0.6900000000000001]:
# MULTICLASS JACCARD [val = 0.8746610283851624, std = 0.07488327473402023]
# BINARY JACCARD [val = 0.9154263734817505, std = 0.05652335658669472]
#
# -----------------------------------------------
# 8/65
# wuunet_224_ow: best_val_bin_acc_9.hdf5
# [wuunet_224_ow_best_val_bin_acc_9.hdf5, threshold = 0.81]:
# MULTICLASS JACCARD [val = 0.7079729437828064, std = 0.16875165700912476]
# BINARY JACCARD [val = 0.8118160367012024, std = 0.11581389605998993]
#
# -----------------------------------------------
# 9/65
# wuunet_224_ow: best_val_mult_acc_604.hdf5
# [wuunet_224_ow_best_val_mult_acc_604.hdf5, threshold = 0.6]:
# MULTICLASS JACCARD [val = 0.8865100741386414, std = 0.07180842757225037]
# BINARY JACCARD [val = 0.9244714975357056, std = 0.05256083980202675]
#
# -----------------------------------------------
# 10/65
# wuunet_224_ow: best_val_mult_acc_661.hdf5
# [wuunet_224_ow_best_val_mult_acc_661.hdf5, threshold = 0.68]:
# MULTICLASS JACCARD [val = 0.8807031512260437, std = 0.07648458331823349]
# BINARY JACCARD [val = 0.9188172221183777, std = 0.05950537696480751]
#
# -----------------------------------------------
# 11/65
# wuunet_224_ow: best_val_mult_acc_690.hdf5
# [wuunet_224_ow_best_val_mult_acc_690.hdf5, threshold = 0.6900000000000001]:
# MULTICLASS JACCARD [val = 0.8807089924812317, std = 0.07650003582239151]
# BINARY JACCARD [val = 0.9187431931495667, std = 0.05960658937692642]
#
# -----------------------------------------------
# 12/65
# wuunet_224_ow: best_val_mult_loss_547.hdf5
# [wuunet_224_ow_best_val_mult_loss_547.hdf5, threshold = 0.24]:
# MULTICLASS JACCARD [val = 0.8777690529823303, std = 0.08239834010601044]
# BINARY JACCARD [val = 0.916968584060669, std = 0.06611856073141098]
#
# -----------------------------------------------
# 13/65
# wuunet_224_ow: best_val_mult_acc_76.hdf5
# [wuunet_224_ow_best_val_mult_acc_76.hdf5, threshold = 0.78]:
# MULTICLASS JACCARD [val = 0.8672839999198914, std = 0.08043608069419861]
# BINARY JACCARD [val = 0.9087879061698914, std = 0.061069343239068985]
#
# -----------------------------------------------
# 14/65
# wuunet_224_ow: best_val_bin_acc_1323.hdf5
# [wuunet_224_ow_best_val_bin_acc_1323.hdf5, threshold = 0.49]:
# MULTICLASS JACCARD [val = 0.8622468709945679, std = 0.08756862580776215]
# BINARY JACCARD [val = 0.9070392847061157, std = 0.07031796872615814]
#
# -----------------------------------------------
# 15/65
# wuunet_224_ow: best_val_mult_acc_2.hdf5
# [wuunet_224_ow_best_val_mult_acc_2.hdf5, threshold = 0.7000000000000001]:
# MULTICLASS JACCARD [val = 0.6343592405319214, std = 0.1657397747039795]
# BINARY JACCARD [val = 0.6627004146575928, std = 0.15362395346164703]
#
# -----------------------------------------------
# 16/65
# wuunet_224_ow: best_val_mult_acc_86.hdf5
# [wuunet_224_ow_best_val_mult_acc_86.hdf5, threshold = 0.58]:
# MULTICLASS JACCARD [val = 0.8713603615760803, std = 0.07725635915994644]
# BINARY JACCARD [val = 0.9125239253044128, std = 0.058725327253341675]
#
# -----------------------------------------------
# 17/65
# wuunet_224_ow: best_val_bin_acc_59.hdf5
# [wuunet_224_ow_best_val_bin_acc_59.hdf5, threshold = 0.8200000000000001]:
# MULTICLASS JACCARD [val = 0.8552798628807068, std = 0.08828108012676239]
# BINARY JACCARD [val = 0.8931604623794556, std = 0.07091693580150604]
#
# -----------------------------------------------
# 18/65
# wuunet_224_ow: best_val_bin_loss_22.hdf5
# [wuunet_224_ow_best_val_bin_loss_22.hdf5, threshold = 0.67]:
# MULTICLASS JACCARD [val = 0.7612629532814026, std = 0.14204521477222443]
# BINARY JACCARD [val = 0.8233428001403809, std = 0.10878824442625046]
#
# -----------------------------------------------
# 19/65
# wuunet_224_ow: best_val_bin_acc_66.hdf5
# [wuunet_224_ow_best_val_bin_acc_66.hdf5, threshold = 0.78]:
# MULTICLASS JACCARD [val = 0.8622876405715942, std = 0.0832134261727333]
# BINARY JACCARD [val = 0.9024530649185181, std = 0.06445715576410294]
#
# -----------------------------------------------
# 20/65
# wuunet_224_ow: best_val_mult_loss_379.hdf5
# [wuunet_224_ow_best_val_mult_loss_379.hdf5, threshold = 0.64]:
# MULTICLASS JACCARD [val = 0.8627344369888306, std = 0.10619332641363144]
# BINARY JACCARD [val = 0.9017762541770935, std = 0.09852103888988495]
#
# -----------------------------------------------
# 21/65
# wuunet_224_ow: best_val_mult_acc_19.hdf5
# [wuunet_224_ow_best_val_mult_acc_19.hdf5, threshold = 0.08]:
# MULTICLASS JACCARD [val = 0.764644205570221, std = 0.1374228298664093]
# BINARY JACCARD [val = 0.8238565921783447, std = 0.10402573645114899]
#
# -----------------------------------------------
# 22/65
# wuunet_224_ow: best_val_bin_acc_58.hdf5
# [wuunet_224_ow_best_val_bin_acc_58.hdf5, threshold = 0.54]:
# MULTICLASS JACCARD [val = 0.8520307540893555, std = 0.09166081994771957]
# BINARY JACCARD [val = 0.8913968205451965, std = 0.07459329813718796]
#
# -----------------------------------------------
# 23/65
# wuunet_224_ow: best_val_bin_acc_621.hdf5
# [wuunet_224_ow_best_val_bin_acc_621.hdf5, threshold = 0.66]:
# MULTICLASS JACCARD [val = 0.884217381477356, std = 0.07378799468278885]
# BINARY JACCARD [val = 0.9220753312110901, std = 0.05542770028114319]
#
# -----------------------------------------------
# 24/65
# wuunet_224_ow: best_val_mult_acc_46.hdf5
# [wuunet_224_ow_best_val_mult_acc_46.hdf5, threshold = 0.79]:
# MULTICLASS JACCARD [val = 0.8201875686645508, std = 0.11199898272752762]
# BINARY JACCARD [val = 0.8581942915916443, std = 0.09962305426597595]
#
# -----------------------------------------------
# 25/65
# wuunet_224_ow: best_val_mult_acc_10.hdf5
# [wuunet_224_ow_best_val_mult_acc_10.hdf5, threshold = 0.2]:
# MULTICLASS JACCARD [val = 0.7107489705085754, std = 0.16069388389587402]
# BINARY JACCARD [val = 0.7707579731941223, std = 0.13394823670387268]
#
# -----------------------------------------------
# 26/65
# wuunet_224_ow: best_val_bin_loss_61.hdf5
# [wuunet_224_ow_best_val_bin_loss_61.hdf5, threshold = 0.59]:
# MULTICLASS JACCARD [val = 0.8520672917366028, std = 0.09418357163667679]
# BINARY JACCARD [val = 0.8946404457092285, std = 0.07591825723648071]
#
# -----------------------------------------------
# 27/65
# wuunet_224_ow: best_val_mult_acc_16.hdf5
# [wuunet_224_ow_best_val_mult_acc_16.hdf5, threshold = 0.65]:
# MULTICLASS JACCARD [val = 0.7482153177261353, std = 0.14021191000938416]
# BINARY JACCARD [val = 0.7976522445678711, std = 0.11697601526975632]
#
# -----------------------------------------------
# 28/65
# wuunet_224_ow: best_val_bin_loss_55.hdf5
# [wuunet_224_ow_best_val_bin_loss_55.hdf5, threshold = 0.77]:
# MULTICLASS JACCARD [val = 0.8347402215003967, std = 0.10332095623016357]
# BINARY JACCARD [val = 0.8746101260185242, std = 0.08898431062698364]
#
# -----------------------------------------------
# 29/65
# wuunet_224_ow: best_val_mult_acc_135.hdf5
# [wuunet_224_ow_best_val_mult_acc_135.hdf5, threshold = 0.68]:
# MULTICLASS JACCARD [val = 0.8771986961364746, std = 0.0725298523902893]
# BINARY JACCARD [val = 0.9173961877822876, std = 0.053862761706113815]
#
# -----------------------------------------------
# 30/65
# wuunet_224_ow: best_val_mult_acc_327.hdf5
# [wuunet_224_ow_best_val_mult_acc_327.hdf5, threshold = 0.75]:
# MULTICLASS JACCARD [val = 0.8635965585708618, std = 0.10373073071241379]
# BINARY JACCARD [val = 0.9021108150482178, std = 0.09608554095029831]
#
# -----------------------------------------------
# 31/65
# wuunet_224_ow: best_val_mult_loss_64.hdf5
# [wuunet_224_ow_best_val_mult_loss_64.hdf5, threshold = 0.6]:
# MULTICLASS JACCARD [val = 0.8499190807342529, std = 0.0946076288819313]
# BINARY JACCARD [val = 0.8919054865837097, std = 0.07943741977214813]
#
# -----------------------------------------------
# 32/65
# wuunet_224_ow: best_val_mult_acc_40.hdf5
# [wuunet_224_ow_best_val_mult_acc_40.hdf5, threshold = 0.85]:
# MULTICLASS JACCARD [val = 0.817723274230957, std = 0.11152339726686478]
# BINARY JACCARD [val = 0.8592365980148315, std = 0.09725283831357956]
#
# -----------------------------------------------
# 33/65
# wuunet_224_ow: best_val_bin_acc_558.hdf5
# [wuunet_224_ow_best_val_bin_acc_558.hdf5, threshold = 0.56]:
# MULTICLASS JACCARD [val = 0.8858739137649536, std = 0.0712628960609436]
# BINARY JACCARD [val = 0.9238773584365845, std = 0.052501074969768524]
#
# -----------------------------------------------
# 34/65
# wuunet_224_ow: best_val_bin_loss_85.hdf5
# [wuunet_224_ow_best_val_bin_loss_85.hdf5, threshold = 0.76]:
# MULTICLASS JACCARD [val = 0.8704612255096436, std = 0.07805127650499344]
# BINARY JACCARD [val = 0.9133018851280212, std = 0.05816846713423729]
#
# -----------------------------------------------
# 35/65
# wuunet_224_ow: best_val_mult_acc_124.hdf5
# [wuunet_224_ow_best_val_mult_acc_124.hdf5, threshold = 0.71]:
# MULTICLASS JACCARD [val = 0.8745715022087097, std = 0.07494683563709259]
# BINARY JACCARD [val = 0.9152136445045471, std = 0.05672706663608551]
#
# -----------------------------------------------
# 36/65
# wuunet_224_ow: best_val_mult_loss_74.hdf5
# [wuunet_224_ow_best_val_mult_loss_74.hdf5, threshold = 0.7000000000000001]:
# MULTICLASS JACCARD [val = 0.8653409481048584, std = 0.08146779239177704]
# BINARY JACCARD [val = 0.9068980813026428, std = 0.06231994926929474]
#
# -----------------------------------------------
# 37/65
# wuunet_224_ow: best_val_mult_acc_553.hdf5
# [wuunet_224_ow_best_val_mult_acc_553.hdf5, threshold = 0.67]:
# MULTICLASS JACCARD [val = 0.8819410800933838, std = 0.07484149932861328]
# BINARY JACCARD [val = 0.9201133251190186, std = 0.057550545781850815]
#
# -----------------------------------------------
# 38/65
# wuunet_224_ow: best_val_mult_acc_314.hdf5
# [wuunet_224_ow_best_val_mult_acc_314.hdf5, threshold = 0.7000000000000001]:
# MULTICLASS JACCARD [val = 0.8746888041496277, std = 0.08323179185390472]
# BINARY JACCARD [val = 0.9130737781524658, std = 0.07187272608280182]
#
# -----------------------------------------------
# 39/65
# wuunet_224_ow: best_val_bin_loss_6.hdf5
# [wuunet_224_ow_best_val_bin_loss_6.hdf5, threshold = 0.91]:
# MULTICLASS JACCARD [val = 0.6771189570426941, std = 0.17384874820709229]
# BINARY JACCARD [val = 0.7187963128089905, std = 0.15137682855129242]
#
# -----------------------------------------------
# 40/65
# wuunet_224_ow: best_val_mult_loss_132.hdf5
# [wuunet_224_ow_best_val_mult_loss_132.hdf5, threshold = 0.68]:
# MULTICLASS JACCARD [val = 0.8768457770347595, std = 0.07318995147943497]
# BINARY JACCARD [val = 0.9169256687164307, std = 0.0547466017305851]
#
# -----------------------------------------------
# 41/65
# wuunet_224_ow: best_val_bin_acc_600.hdf5
# [wuunet_224_ow_best_val_bin_acc_600.hdf5, threshold = 0.62]:
# MULTICLASS JACCARD [val = 0.8879469037055969, std = 0.07026683539152145]
# BINARY JACCARD [val = 0.9257318377494812, std = 0.050718553364276886]
#
# -----------------------------------------------
# 42/65
# wuunet_224_ow: best_val_mult_loss_36.hdf5
# [wuunet_224_ow_best_val_mult_loss_36.hdf5, threshold = 0.3]:
# MULTICLASS JACCARD [val = 0.7900501489639282, std = 0.1211252510547638]
# BINARY JACCARD [val = 0.8485023975372314, std = 0.09554313123226166]
#
# -----------------------------------------------
# 43/65
# wuunet_224_ow: best_val_mult_acc_369.hdf5
# [wuunet_224_ow_best_val_mult_acc_369.hdf5, threshold = 0.67]:
# MULTICLASS JACCARD [val = 0.8642454147338867, std = 0.1031702309846878]
# BINARY JACCARD [val = 0.9032636880874634, std = 0.09524189680814743]
#
# -----------------------------------------------
# 44/65
# wuunet_224_ow: best_val_bin_loss_568.hdf5
# [wuunet_224_ow_best_val_bin_loss_568.hdf5, threshold = 0.5]:
# MULTICLASS JACCARD [val = 0.8841456770896912, std = 0.07312630861997604]
# BINARY JACCARD [val = 0.923279881477356, std = 0.05426539108157158]
#
# -----------------------------------------------
# 45/65
# wuunet_224_ow: best_val_mult_acc_75.hdf5
# [wuunet_224_ow_best_val_mult_acc_75.hdf5, threshold = 0.62]:
# MULTICLASS JACCARD [val = 0.8674677610397339, std = 0.08072435855865479]
# BINARY JACCARD [val = 0.908534049987793, std = 0.06201387941837311]
#
# -----------------------------------------------
# 46/65
# wuunet_224_ow: best_val_mult_acc_32.hdf5
# [wuunet_224_ow_best_val_mult_acc_32.hdf5, threshold = 0.03]:
# MULTICLASS JACCARD [val = 0.8101328611373901, std = 0.10927700251340866]
# BINARY JACCARD [val = 0.8533289432525635, std = 0.09350435435771942]
#
# -----------------------------------------------
# 47/65
# wuunet_224_ow: best_val_mult_loss_1.hdf5
# [wuunet_224_ow_best_val_mult_loss_1.hdf5, threshold = 0.33]:
# MULTICLASS JACCARD [val = 0.5653433799743652, std = 0.20911423861980438]
# BINARY JACCARD [val = 0.5653433799743652, std = 0.20911423861980438]
#
# -----------------------------------------------
# 48/65
# wuunet_224_ow: best_val_bin_acc_15.hdf5
# [wuunet_224_ow_best_val_bin_acc_15.hdf5, threshold = 0.01]:
# MULTICLASS JACCARD [val = 0.6578516364097595, std = 0.14972011744976044]
# BINARY JACCARD [val = 0.7378027439117432, std = 0.11971177905797958]
#
# -----------------------------------------------
# 49/65
# wuunet_224_ow: best_val_bin_acc_45.hdf5
# [wuunet_224_ow_best_val_bin_acc_45.hdf5, threshold = 0.84]:
# MULTICLASS JACCARD [val = 0.8142971396446228, std = 0.12100132554769516]
# BINARY JACCARD [val = 0.8508362770080566, std = 0.10874994844198227]
#
# -----------------------------------------------
# 50/65
# wuunet_224_ow: best_val_mult_acc_54.hdf5
# [wuunet_224_ow_best_val_mult_acc_54.hdf5, threshold = 0.78]:
# MULTICLASS JACCARD [val = 0.8392406702041626, std = 0.0986023023724556]
# BINARY JACCARD [val = 0.8788495659828186, std = 0.08223623782396317]
#
# -----------------------------------------------
# 51/65
# wuunet_224_ow: best_val_bin_acc_52.hdf5
# [wuunet_224_ow_best_val_bin_acc_52.hdf5, threshold = 0.75]:
# MULTICLASS JACCARD [val = 0.8388270735740662, std = 0.09924516081809998]
# BINARY JACCARD [val = 0.8778283596038818, std = 0.08156444877386093]
#
# -----------------------------------------------
# 52/65
# wuunet_224_ow: best_val_mult_acc_355.hdf5
# [wuunet_224_ow_best_val_mult_acc_355.hdf5, threshold = 0.67]:
# MULTICLASS JACCARD [val = 0.8640573024749756, std = 0.10373234003782272]
# BINARY JACCARD [val = 0.90305495262146, std = 0.0960007980465889]
#
# -----------------------------------------------
# 53/65
# wuunet_224_ow: best_val_mult_acc_677.hdf5
# [wuunet_224_ow_best_val_mult_acc_677.hdf5, threshold = 0.68]:
# MULTICLASS JACCARD [val = 0.8806758522987366, std = 0.07652126997709274]
# BINARY JACCARD [val = 0.9187709093093872, std = 0.05956175550818443]
#
# -----------------------------------------------
# 54/65
# wuunet_224_ow: best_val_mult_acc_290.hdf5
# [wuunet_224_ow_best_val_mult_acc_290.hdf5, threshold = 0.87]:
# MULTICLASS JACCARD [val = 0.8726609945297241, std = 0.0800773873925209]
# BINARY JACCARD [val = 0.9091707468032837, std = 0.0664251372218132]
#
# -----------------------------------------------
# 55/65
# wuunet_224_ow: best_val_bin_acc_940.hdf5
# [wuunet_224_ow_best_val_bin_acc_940.hdf5, threshold = 0.48]:
# MULTICLASS JACCARD [val = 0.870977520942688, std = 0.0861940011382103]
# BINARY JACCARD [val = 0.9102556705474854, std = 0.07200226187705994]
#
# -----------------------------------------------
# 56/65
# wuunet_224_ow: best_val_mult_acc_3.hdf5
# [wuunet_224_ow_best_val_mult_acc_3.hdf5, threshold = 0.93]:
# MULTICLASS JACCARD [val = 0.6355254650115967, std = 0.1623128354549408]
# BINARY JACCARD [val = 0.6621633172035217, std = 0.15318161249160767]
#
# -----------------------------------------------
# 57/65
# wuunet_224_ow: best_val_mult_loss_122.hdf5
# [wuunet_224_ow_best_val_mult_loss_122.hdf5, threshold = 0.67]:
# MULTICLASS JACCARD [val = 0.8749212026596069, std = 0.07472959905862808]
# BINARY JACCARD [val = 0.9156714081764221, std = 0.0564211905002594]
#
# -----------------------------------------------
# 58/65
# wuunet_224_ow: best_val_bin_acc_51.hdf5
# [wuunet_224_ow_best_val_bin_acc_51.hdf5, threshold = 0.8]:
# MULTICLASS JACCARD [val = 0.83062744140625, std = 0.10560198873281479]
# BINARY JACCARD [val = 0.8734459280967712, std = 0.08645115792751312]
#
# -----------------------------------------------
# 59/65
# wuunet_224_ow: best_val_mult_loss_60.hdf5
# [wuunet_224_ow_best_val_mult_loss_60.hdf5, threshold = 0.73]:
# MULTICLASS JACCARD [val = 0.857506513595581, std = 0.09002720564603806]
# BINARY JACCARD [val = 0.896734893321991, std = 0.07223163545131683]
#
# -----------------------------------------------
# 60/65
# wuunet_224_ow: best_val_mult_loss_546.hdf5
# [wuunet_224_ow_best_val_mult_loss_546.hdf5, threshold = 0.81]:
# MULTICLASS JACCARD [val = 0.8799055218696594, std = 0.0762353241443634]
# BINARY JACCARD [val = 0.917782723903656, std = 0.062119219452142715]
#
# -----------------------------------------------
# 61/65
# wuunet_224_ow: best_val_bin_acc_50.hdf5
# [wuunet_224_ow_best_val_bin_acc_50.hdf5, threshold = 0.98]:
# MULTICLASS JACCARD [val = 0.8155922293663025, std = 0.11380679905414581]
# BINARY JACCARD [val = 0.8566178679466248, std = 0.09736228734254837]
#
# -----------------------------------------------
# 62/65
# wuunet_224_ow: best_val_mult_acc_53.hdf5
# [wuunet_224_ow_best_val_mult_acc_53.hdf5, threshold = 0.8]:
# MULTICLASS JACCARD [val = 0.8376993536949158, std = 0.09954523295164108]
# BINARY JACCARD [val = 0.8773325681686401, std = 0.08325685560703278]
#
# -----------------------------------------------
# 63/65
# wuunet_224_ow: best_val_bin_acc_57.hdf5
# [wuunet_224_ow_best_val_bin_acc_57.hdf5, threshold = 0.85]:
# MULTICLASS JACCARD [val = 0.8461557626724243, std = 0.096047542989254]
# BINARY JACCARD [val = 0.883514404296875, std = 0.08052138984203339]
#
# -----------------------------------------------
# 64/65
# wuunet_224_ow: best_val_mult_loss_4.hdf5
# [wuunet_224_ow_best_val_mult_loss_4.hdf5, threshold = 0.01]:
# MULTICLASS JACCARD [val = 0.6382783651351929, std = 0.18902833759784698]
# BINARY JACCARD [val = 0.6723340153694153, std = 0.1741386204957962]
#
# ================================================
# SUMMARY:
# Jaccard bin  mean max: name = wuunet_224_ow_best_val_bin_acc_600.hdf5, value = 0.9257318377494812, thr = 0.62
# Jaccard bin  std min:  name = wuunet_224_ow_best_val_bin_acc_600.hdf5, value = 0.050718553364276886, thr = 0.62
# Jaccard mult mean max: name = wuunet_224_ow_best_val_bin_acc_600.hdf5, value = 0.8879469037055969, thr = 0.62
# Jaccard mult std min:  name = wuunet_224_ow_best_val_bin_acc_600.hdf5, value = 0.07026683539152145, thr = 0.62
# ================================================
# ================================================
# wuunet_light_224_ow
# -----------------------------------------------
# 0/85
# wuunet_light_224_ow: best_val_bin_acc_17.hdf5
# [wuunet_light_224_ow_best_val_bin_acc_17.hdf5, threshold = 0.01]:
# MULTICLASS JACCARD [val = 0.6970822215080261, std = 0.1573047786951065]
# BINARY JACCARD [val = 0.7634769678115845, std = 0.12658563256263733]
#
# -----------------------------------------------
# 1/85
# wuunet_light_224_ow: best_val_bin_acc_104.hdf5
# [wuunet_light_224_ow_best_val_bin_acc_104.hdf5, threshold = 0.44]:
# MULTICLASS JACCARD [val = 0.8406528234481812, std = 0.09466701000928879]
# BINARY JACCARD [val = 0.8853569626808167, std = 0.07436962425708771]
#
# -----------------------------------------------
# 2/85
# wuunet_light_224_ow: best_val_mult_loss_120.hdf5
# [wuunet_light_224_ow_best_val_mult_loss_120.hdf5, threshold = 0.53]:
# MULTICLASS JACCARD [val = 0.8423459529876709, std = 0.08999283611774445]
# BINARY JACCARD [val = 0.8872237205505371, std = 0.0694689080119133]
#
# -----------------------------------------------
# 3/85
# wuunet_light_224_ow: best_val_mult_acc_54.hdf5
# [wuunet_light_224_ow_best_val_mult_acc_54.hdf5, threshold = 0.51]:
# MULTICLASS JACCARD [val = 0.816656768321991, std = 0.09465334564447403]
# BINARY JACCARD [val = 0.8637489676475525, std = 0.07572462409734726]
#
# -----------------------------------------------
# 4/85
# wuunet_light_224_ow: best_val_mult_acc_5.hdf5
# [wuunet_light_224_ow_best_val_mult_acc_5.hdf5, threshold = 0.17]:
# MULTICLASS JACCARD [val = 0.5881091952323914, std = 0.18457673490047455]
# BINARY JACCARD [val = 0.730044424533844, std = 0.16054865717887878]
#
# -----------------------------------------------
# 5/85
# wuunet_light_224_ow: best_val_mult_acc_14.hdf5
# [wuunet_light_224_ow_best_val_mult_acc_14.hdf5, threshold = 0.37]:
# MULTICLASS JACCARD [val = 0.7010120749473572, std = 0.15753582119941711]
# BINARY JACCARD [val = 0.7743555903434753, std = 0.13074597716331482]
#
# -----------------------------------------------
# 6/85
# wuunet_light_224_ow: best_val_mult_acc_13.hdf5
# [wuunet_light_224_ow_best_val_mult_acc_13.hdf5, threshold = 0.34]:
# MULTICLASS JACCARD [val = 0.69073086977005, std = 0.17395810782909393]
# BINARY JACCARD [val = 0.7620433568954468, std = 0.14487461745738983]
#
# -----------------------------------------------
# 7/85
# wuunet_light_224_ow: best_val_bin_acc_279.hdf5
# [wuunet_light_224_ow_best_val_bin_acc_279.hdf5, threshold = 0.6900000000000001]:
# MULTICLASS JACCARD [val = 0.8504899740219116, std = 0.08713644742965698]
# BINARY JACCARD [val = 0.8894743919372559, std = 0.06899359822273254]
#
# -----------------------------------------------
# 8/85
# wuunet_light_224_ow: best_val_mult_acc_373.hdf5
# [wuunet_light_224_ow_best_val_mult_acc_373.hdf5, threshold = 0.53]:
# MULTICLASS JACCARD [val = 0.8628965616226196, std = 0.07933197170495987]
# BINARY JACCARD [val = 0.9036439657211304, std = 0.05807393416762352]
#
# -----------------------------------------------
# 9/85
# wuunet_light_224_ow: best_val_mult_loss_188.hdf5
# [wuunet_light_224_ow_best_val_mult_loss_188.hdf5, threshold = 0.58]:
# MULTICLASS JACCARD [val = 0.8456064462661743, std = 0.08806955814361572]
# BINARY JACCARD [val = 0.8896976113319397, std = 0.06683734059333801]
#
# -----------------------------------------------
# 10/85
# wuunet_light_224_ow: best_val_bin_loss_9.hdf5
# [wuunet_light_224_ow_best_val_bin_loss_9.hdf5, threshold = 0.9]:
# MULTICLASS JACCARD [val = 0.6838874220848083, std = 0.18286465108394623]
# BINARY JACCARD [val = 0.7753484845161438, std = 0.13449259102344513]
#
# -----------------------------------------------
# 11/85
# wuunet_light_224_ow: best_val_mult_loss_53.hdf5
# [wuunet_light_224_ow_best_val_mult_loss_53.hdf5, threshold = 0.6]:
# MULTICLASS JACCARD [val = 0.8168113827705383, std = 0.09381632506847382]
# BINARY JACCARD [val = 0.8636525869369507, std = 0.07513990998268127]
#
# -----------------------------------------------
# 12/85
# wuunet_light_224_ow: best_val_mult_acc_555.hdf5
# [wuunet_light_224_ow_best_val_mult_acc_555.hdf5, threshold = 0.53]:
# MULTICLASS JACCARD [val = 0.8654741048812866, std = 0.08108964562416077]
# BINARY JACCARD [val = 0.9036423563957214, std = 0.06018390879034996]
#
# -----------------------------------------------
# 13/85
# wuunet_light_224_ow: best_val_bin_acc_1834.hdf5
# [wuunet_light_224_ow_best_val_bin_acc_1834.hdf5, threshold = 0.49]:
# MULTICLASS JACCARD [val = 0.8573293685913086, std = 0.08918231725692749]
# BINARY JACCARD [val = 0.9047420620918274, std = 0.059195149689912796]
#
# -----------------------------------------------
# 14/85
# wuunet_light_224_ow: best_val_mult_acc_551.hdf5
# [wuunet_light_224_ow_best_val_mult_acc_551.hdf5, threshold = 0.65]:
# MULTICLASS JACCARD [val = 0.8661776781082153, std = 0.08025075495243073]
# BINARY JACCARD [val = 0.9033960700035095, std = 0.060211796313524246]
#
# -----------------------------------------------
# 15/85
# wuunet_light_224_ow: best_val_mult_loss_35.hdf5
# [wuunet_light_224_ow_best_val_mult_loss_35.hdf5, threshold = 0.89]:
# MULTICLASS JACCARD [val = 0.7953699827194214, std = 0.10819397866725922]
# BINARY JACCARD [val = 0.8390183448791504, std = 0.0940684899687767]
#
# -----------------------------------------------
# 16/85
# wuunet_light_224_ow: best_val_bin_acc_50.hdf5
# [wuunet_light_224_ow_best_val_bin_acc_50.hdf5, threshold = 0.91]:
# MULTICLASS JACCARD [val = 0.8130576610565186, std = 0.09500078856945038]
# BINARY JACCARD [val = 0.8613221049308777, std = 0.07442421466112137]
#
# -----------------------------------------------
# 17/85
# wuunet_light_224_ow: best_val_bin_acc_12.hdf5
# [wuunet_light_224_ow_best_val_bin_acc_12.hdf5, threshold = 0.86]:
# MULTICLASS JACCARD [val = 0.6816344261169434, std = 0.17556940019130707]
# BINARY JACCARD [val = 0.7507159113883972, std = 0.14610601961612701]
#
# -----------------------------------------------
# 18/85
# wuunet_light_224_ow: best_val_bin_loss_33.hdf5
# [wuunet_light_224_ow_best_val_bin_loss_33.hdf5, threshold = 0.97]:
# MULTICLASS JACCARD [val = 0.7577279806137085, std = 0.14301571249961853]
# BINARY JACCARD [val = 0.8091590404510498, std = 0.11291586607694626]
#
# -----------------------------------------------
# 19/85
# wuunet_light_224_ow: best_val_mult_acc_171.hdf5
# [wuunet_light_224_ow_best_val_mult_acc_171.hdf5, threshold = 0.5700000000000001]:
# MULTICLASS JACCARD [val = 0.8455164432525635, std = 0.08833922445774078]
# BINARY JACCARD [val = 0.8898235559463501, std = 0.06681845337152481]
#
# -----------------------------------------------
# 20/85
# wuunet_light_224_ow: best_val_bin_acc_281.hdf5
# [wuunet_light_224_ow_best_val_bin_acc_281.hdf5, threshold = 0.29]:
# MULTICLASS JACCARD [val = 0.8515521883964539, std = 0.08243323117494583]
# BINARY JACCARD [val = 0.8988832235336304, std = 0.058724984526634216]
#
# -----------------------------------------------
# 21/85
# wuunet_light_224_ow: best_val_mult_acc_2.hdf5
# [wuunet_light_224_ow_best_val_mult_acc_2.hdf5, threshold = 0.37]:
# MULTICLASS JACCARD [val = 0.5653433799743652, std = 0.20911423861980438]
# BINARY JACCARD [val = 0.5653433799743652, std = 0.20911423861980438]
#
# -----------------------------------------------
# 22/85
# wuunet_light_224_ow: best_val_mult_acc_86.hdf5
# [wuunet_light_224_ow_best_val_mult_acc_86.hdf5, threshold = 0.49]:
# MULTICLASS JACCARD [val = 0.8375290036201477, std = 0.0875578224658966]
# BINARY JACCARD [val = 0.8843643069267273, std = 0.06565403938293457]
#
# -----------------------------------------------
# 23/85
# wuunet_light_224_ow: best_val_mult_acc_22.hdf5
# [wuunet_light_224_ow_best_val_mult_acc_22.hdf5, threshold = 0.81]:
# MULTICLASS JACCARD [val = 0.7528038024902344, std = 0.1225244477391243]
# BINARY JACCARD [val = 0.8102052211761475, std = 0.09642766416072845]
#
# -----------------------------------------------
# 24/85
# wuunet_light_224_ow: best_val_mult_acc_48.hdf5
# [wuunet_light_224_ow_best_val_mult_acc_48.hdf5, threshold = 0.51]:
# MULTICLASS JACCARD [val = 0.7899907827377319, std = 0.1043451800942421]
# BINARY JACCARD [val = 0.8371707797050476, std = 0.09000150859355927]
#
# -----------------------------------------------
# 25/85
# wuunet_light_224_ow: best_val_mult_acc_19.hdf5
# [wuunet_light_224_ow_best_val_mult_acc_19.hdf5, threshold = 0.01]:
# MULTICLASS JACCARD [val = 0.717869222164154, std = 0.14480654895305634]
# BINARY JACCARD [val = 0.7776594161987305, std = 0.13047367334365845]
#
# -----------------------------------------------
# 26/85
# wuunet_light_224_ow: best_val_bin_acc_591.hdf5
# [wuunet_light_224_ow_best_val_bin_acc_591.hdf5, threshold = 0.59]:
# MULTICLASS JACCARD [val = 0.8680188655853271, std = 0.07815041393041611]
# BINARY JACCARD [val = 0.9062579870223999, std = 0.05685023218393326]
#
# -----------------------------------------------
# 27/85
# wuunet_light_224_ow: best_val_bin_acc_46.hdf5
# [wuunet_light_224_ow_best_val_bin_acc_46.hdf5, threshold = 0.9400000000000001]:
# MULTICLASS JACCARD [val = 0.7930898666381836, std = 0.11596878618001938]
# BINARY JACCARD [val = 0.8320333957672119, std = 0.09790042042732239]
#
# -----------------------------------------------
# 28/85
# wuunet_light_224_ow: best_val_bin_acc_69.hdf5
# [wuunet_light_224_ow_best_val_bin_acc_69.hdf5, threshold = 0.79]:
# MULTICLASS JACCARD [val = 0.8332503437995911, std = 0.092926524579525]
# BINARY JACCARD [val = 0.8754030466079712, std = 0.07517315447330475]
#
# -----------------------------------------------
# 29/85
# wuunet_light_224_ow: best_val_mult_loss_811.hdf5
# [wuunet_light_224_ow_best_val_mult_loss_811.hdf5, threshold = 0.55]:
# MULTICLASS JACCARD [val = 0.8701801896095276, std = 0.07599328458309174]
# BINARY JACCARD [val = 0.909412145614624, std = 0.05400967597961426]
#
# -----------------------------------------------
# 30/85
# wuunet_light_224_ow: best_val_mult_acc_70.hdf5
# [wuunet_light_224_ow_best_val_mult_acc_70.hdf5, threshold = 0.8]:
# MULTICLASS JACCARD [val = 0.8338488340377808, std = 0.08865277469158173]
# BINARY JACCARD [val = 0.875873327255249, std = 0.07161708921194077]
#
# -----------------------------------------------
# 31/85
# wuunet_light_224_ow: best_val_mult_acc_61.hdf5
# [wuunet_light_224_ow_best_val_mult_acc_61.hdf5, threshold = 0.52]:
# MULTICLASS JACCARD [val = 0.8232287168502808, std = 0.088581383228302]
# BINARY JACCARD [val = 0.8685760498046875, std = 0.0694982036948204]
#
# -----------------------------------------------
# 32/85
# wuunet_light_224_ow: best_val_mult_acc_103.hdf5
# [wuunet_light_224_ow_best_val_mult_acc_103.hdf5, threshold = 0.5]:
# MULTICLASS JACCARD [val = 0.8409223556518555, std = 0.09469213336706161]
# BINARY JACCARD [val = 0.8850827813148499, std = 0.07471358776092529]
#
# -----------------------------------------------
# 33/85
# wuunet_light_224_ow: best_val_mult_acc_367.hdf5
# [wuunet_light_224_ow_best_val_mult_acc_367.hdf5, threshold = 0.5700000000000001]:
# MULTICLASS JACCARD [val = 0.8627221584320068, std = 0.07980357110500336]
# BINARY JACCARD [val = 0.9032977819442749, std = 0.058602992445230484]
#
# -----------------------------------------------
# 34/85
# wuunet_light_224_ow: best_val_mult_loss_21.hdf5
# [wuunet_light_224_ow_best_val_mult_loss_21.hdf5, threshold = 0.01]:
# MULTICLASS JACCARD [val = 0.72715163230896, std = 0.14221814274787903]
# BINARY JACCARD [val = 0.7924879193305969, std = 0.1091533675789833]
#
# -----------------------------------------------
# 35/85
# wuunet_light_224_ow: best_val_mult_loss_30.hdf5
# [wuunet_light_224_ow_best_val_mult_loss_30.hdf5, threshold = 0.87]:
# MULTICLASS JACCARD [val = 0.7724580764770508, std = 0.12338460981845856]
# BINARY JACCARD [val = 0.8195502758026123, std = 0.10703235119581223]
#
# -----------------------------------------------
# 36/85
# wuunet_light_224_ow: best_val_bin_acc_307.hdf5
# [wuunet_light_224_ow_best_val_bin_acc_307.hdf5, threshold = 0.7000000000000001]:
# MULTICLASS JACCARD [val = 0.8571993708610535, std = 0.08125246316194534]
# BINARY JACCARD [val = 0.9006717801094055, std = 0.06024397537112236]
#
# -----------------------------------------------
# 37/85
# wuunet_light_224_ow: best_val_mult_acc_274.hdf5
# [wuunet_light_224_ow_best_val_mult_acc_274.hdf5, threshold = 0.75]:
# MULTICLASS JACCARD [val = 0.8522379398345947, std = 0.08466369658708572]
# BINARY JACCARD [val = 0.8958716988563538, std = 0.0624399334192276]
#
# -----------------------------------------------
# 38/85
# wuunet_light_224_ow: best_val_mult_loss_4.hdf5
# [wuunet_light_224_ow_best_val_mult_loss_4.hdf5, threshold = 0.01]:
# MULTICLASS JACCARD [val = 0.6419928669929504, std = 0.16992133855819702]
# BINARY JACCARD [val = 0.6898292899131775, std = 0.14967776834964752]
#
# -----------------------------------------------
# 39/85
# wuunet_light_224_ow: best_val_bin_loss_100.hdf5
# [wuunet_light_224_ow_best_val_bin_loss_100.hdf5, threshold = 0.5700000000000001]:
# MULTICLASS JACCARD [val = 0.8399748802185059, std = 0.09545926749706268]
# BINARY JACCARD [val = 0.8832277059555054, std = 0.07656179368495941]
#
# -----------------------------------------------
# 40/85
# wuunet_light_224_ow: best_val_mult_acc_792.hdf5
# [wuunet_light_224_ow_best_val_mult_acc_792.hdf5, threshold = 0.25]:
# MULTICLASS JACCARD [val = 0.8722360134124756, std = 0.07470056414604187]
# BINARY JACCARD [val = 0.9111632704734802, std = 0.05444585531949997]
#
# -----------------------------------------------
# 41/85
# wuunet_light_224_ow: best_val_mult_acc_85.hdf5
# [wuunet_light_224_ow_best_val_mult_acc_85.hdf5, threshold = 0.37]:
# MULTICLASS JACCARD [val = 0.8368244767189026, std = 0.09465773403644562]
# BINARY JACCARD [val = 0.8810421228408813, std = 0.0754028707742691]
#
# -----------------------------------------------
# 42/85
# wuunet_light_224_ow: best_val_mult_loss_208.hdf5
# [wuunet_light_224_ow_best_val_mult_loss_208.hdf5, threshold = 0.5700000000000001]:
# MULTICLASS JACCARD [val = 0.8455682992935181, std = 0.08829708397388458]
# BINARY JACCARD [val = 0.889685869216919, std = 0.06701458245515823]
#
# -----------------------------------------------
# 43/85
# wuunet_light_224_ow: best_val_bin_loss_222.hdf5
# [wuunet_light_224_ow_best_val_bin_loss_222.hdf5, threshold = 0.5700000000000001]:
# MULTICLASS JACCARD [val = 0.8455595970153809, std = 0.08831145614385605]
# BINARY JACCARD [val = 0.8896944522857666, std = 0.06701850891113281]
#
# -----------------------------------------------
# 44/85
# wuunet_light_224_ow: best_val_mult_acc_55.hdf5
# [wuunet_light_224_ow_best_val_mult_acc_55.hdf5, threshold = 0.6]:
# MULTICLASS JACCARD [val = 0.8198418617248535, std = 0.09203435480594635]
# BINARY JACCARD [val = 0.8649153709411621, std = 0.07407109439373016]
#
# -----------------------------------------------
# 45/85
# wuunet_light_224_ow: best_val_mult_acc_20.hdf5
# [wuunet_light_224_ow_best_val_mult_acc_20.hdf5, threshold = 0.87]:
# MULTICLASS JACCARD [val = 0.732300341129303, std = 0.1466345638036728]
# BINARY JACCARD [val = 0.788905143737793, std = 0.12648434937000275]
#
# -----------------------------------------------
# 46/85
# wuunet_light_224_ow: best_val_bin_loss_28.hdf5
# [wuunet_light_224_ow_best_val_bin_loss_28.hdf5, threshold = 0.03]:
# MULTICLASS JACCARD [val = 0.737523078918457, std = 0.15089252591133118]
# BINARY JACCARD [val = 0.8081352114677429, std = 0.11453937739133835]
#
# -----------------------------------------------
# 47/85
# wuunet_light_224_ow: best_val_bin_acc_57.hdf5
# [wuunet_light_224_ow_best_val_bin_acc_57.hdf5, threshold = 0.31]:
# MULTICLASS JACCARD [val = 0.8187074065208435, std = 0.09398243576288223]
# BINARY JACCARD [val = 0.8653958439826965, std = 0.07443945109844208]
#
# -----------------------------------------------
# 48/85
# wuunet_light_224_ow: best_val_bin_acc_8.hdf5
# [wuunet_light_224_ow_best_val_bin_acc_8.hdf5, threshold = 0.01]:
# MULTICLASS JACCARD [val = 0.5905696153640747, std = 0.18510913848876953]
# BINARY JACCARD [val = 0.6364740133285522, std = 0.16849644482135773]
#
# -----------------------------------------------
# 49/85
# wuunet_light_224_ow: best_val_mult_loss_29.hdf5
# [wuunet_light_224_ow_best_val_mult_loss_29.hdf5, threshold = 0.92]:
# MULTICLASS JACCARD [val = 0.7654202580451965, std = 0.11269498616456985]
# BINARY JACCARD [val = 0.8169150352478027, std = 0.10120433568954468]
#
# -----------------------------------------------
# 50/85
# wuunet_light_224_ow: best_val_bin_loss_6.hdf5
# [wuunet_light_224_ow_best_val_bin_loss_6.hdf5, threshold = 0.07]:
# MULTICLASS JACCARD [val = 0.6187052130699158, std = 0.19358476996421814]
# BINARY JACCARD [val = 0.7425963878631592, std = 0.15722644329071045]
#
# -----------------------------------------------
# 51/85
# wuunet_light_224_ow: best_val_bin_acc_692.hdf5
# [wuunet_light_224_ow_best_val_bin_acc_692.hdf5, threshold = 0.52]:
# MULTICLASS JACCARD [val = 0.8670913577079773, std = 0.07952088862657547]
# BINARY JACCARD [val = 0.9060204029083252, std = 0.05737759545445442]
#
# -----------------------------------------------
# 52/85
# wuunet_light_224_ow: best_val_mult_acc_322.hdf5
# [wuunet_light_224_ow_best_val_mult_acc_322.hdf5, threshold = 0.66]:
# MULTICLASS JACCARD [val = 0.8600577712059021, std = 0.08106958866119385]
# BINARY JACCARD [val = 0.9011909365653992, std = 0.06061839312314987]
#
# -----------------------------------------------
# 53/85
# wuunet_light_224_ow: best_val_bin_acc_344.hdf5
# [wuunet_light_224_ow_best_val_bin_acc_344.hdf5, threshold = 0.5]:
# MULTICLASS JACCARD [val = 0.8602823615074158, std = 0.08189543336629868]
# BINARY JACCARD [val = 0.9016757607460022, std = 0.06042725220322609]
#
# -----------------------------------------------
# 54/85
# wuunet_light_224_ow: best_val_mult_loss_237.hdf5
# [wuunet_light_224_ow_best_val_mult_loss_237.hdf5, threshold = 0.5700000000000001]:
# MULTICLASS JACCARD [val = 0.8455359935760498, std = 0.08830246329307556]
# BINARY JACCARD [val = 0.8897101879119873, std = 0.06702343374490738]
#
# -----------------------------------------------
# 55/85
# wuunet_light_224_ow: best_val_bin_loss_1832.hdf5
# [wuunet_light_224_ow_best_val_bin_loss_1832.hdf5, threshold = 0.33]:
# MULTICLASS JACCARD [val = 0.8581042885780334, std = 0.08865578472614288]
# BINARY JACCARD [val = 0.905701756477356, std = 0.0590701624751091]
#
# -----------------------------------------------
# 56/85
# wuunet_light_224_ow: best_val_bin_acc_357.hdf5
# [wuunet_light_224_ow_best_val_bin_acc_357.hdf5, threshold = 0.54]:
# MULTICLASS JACCARD [val = 0.8617866039276123, std = 0.07949723303318024]
# BINARY JACCARD [val = 0.9026273488998413, std = 0.05931851267814636]
#
# -----------------------------------------------
# 57/85
# wuunet_light_224_ow: best_val_mult_loss_1.hdf5
# [wuunet_light_224_ow_best_val_mult_loss_1.hdf5, threshold = 0.6]:
# MULTICLASS JACCARD [val = 0.5653433799743652, std = 0.20911423861980438]
# BINARY JACCARD [val = 0.5653433799743652, std = 0.20911423861980438]
#
# -----------------------------------------------
# 58/85
# wuunet_light_224_ow: best_val_mult_acc_766.hdf5
# [wuunet_light_224_ow_best_val_mult_acc_766.hdf5, threshold = 0.43]:
# MULTICLASS JACCARD [val = 0.8676229119300842, std = 0.07771502435207367]
# BINARY JACCARD [val = 0.9066832661628723, std = 0.05546744912862778]
#
# -----------------------------------------------
# 59/85
# wuunet_light_224_ow: best_val_mult_acc_360.hdf5
# [wuunet_light_224_ow_best_val_mult_acc_360.hdf5, threshold = 0.53]:
# MULTICLASS JACCARD [val = 0.8623237013816833, std = 0.07954870909452438]
# BINARY JACCARD [val = 0.9029869437217712, std = 0.059107936918735504]
#
# -----------------------------------------------
# 60/85
# wuunet_light_224_ow: best_val_bin_acc_619.hdf5
# [wuunet_light_224_ow_best_val_bin_acc_619.hdf5, threshold = 0.54]:
# MULTICLASS JACCARD [val = 0.8678113222122192, std = 0.07885654270648956]
# BINARY JACCARD [val = 0.9061708450317383, std = 0.05726613849401474]
#
# -----------------------------------------------
# 61/85
# wuunet_light_224_ow: best_val_bin_acc_10.hdf5
# [wuunet_light_224_ow_best_val_bin_acc_10.hdf5, threshold = 0.01]:
# MULTICLASS JACCARD [val = 0.6466324329376221, std = 0.16481012105941772]
# BINARY JACCARD [val = 0.7083590030670166, std = 0.1476094126701355]
#
# -----------------------------------------------
# 62/85
# wuunet_light_224_ow: best_val_mult_loss_142.hdf5
# [wuunet_light_224_ow_best_val_mult_loss_142.hdf5, threshold = 0.5700000000000001]:
# MULTICLASS JACCARD [val = 0.844813346862793, std = 0.08851537108421326]
# BINARY JACCARD [val = 0.8895648717880249, std = 0.06702561676502228]
#
# -----------------------------------------------
# 63/85
# wuunet_light_224_ow: best_val_mult_acc_116.hdf5
# [wuunet_light_224_ow_best_val_mult_acc_116.hdf5, threshold = 0.5700000000000001]:
# MULTICLASS JACCARD [val = 0.8421205282211304, std = 0.08965454250574112]
# BINARY JACCARD [val = 0.8867455124855042, std = 0.06962757557630539]
#
# -----------------------------------------------
# 64/85
# wuunet_light_224_ow: best_val_bin_acc_810.hdf5
# [wuunet_light_224_ow_best_val_bin_acc_810.hdf5, threshold = 0.54]:
# MULTICLASS JACCARD [val = 0.8697888851165771, std = 0.07639321684837341]
# BINARY JACCARD [val = 0.9094592928886414, std = 0.05413869023323059]
#
# -----------------------------------------------
# 65/85
# wuunet_light_224_ow: best_val_mult_acc_115.hdf5
# [wuunet_light_224_ow_best_val_mult_acc_115.hdf5, threshold = 0.54]:
# MULTICLASS JACCARD [val = 0.8423378467559814, std = 0.08972585201263428]
# BINARY JACCARD [val = 0.8868619203567505, std = 0.06957153230905533]
#
# -----------------------------------------------
# 66/85
# wuunet_light_224_ow: best_val_bin_acc_945.hdf5
# [wuunet_light_224_ow_best_val_bin_acc_945.hdf5, threshold = 0.43]:
# MULTICLASS JACCARD [val = 0.8691005110740662, std = 0.07814966142177582]
# BINARY JACCARD [val = 0.9094899296760559, std = 0.05456862598657608]
#
# -----------------------------------------------
# 67/85
# wuunet_light_224_ow: best_val_mult_loss_107.hdf5
# [wuunet_light_224_ow_best_val_mult_loss_107.hdf5, threshold = 0.44]:
# MULTICLASS JACCARD [val = 0.8409276604652405, std = 0.09245666116476059]
# BINARY JACCARD [val = 0.8860793113708496, std = 0.07185409218072891]
#
# -----------------------------------------------
# 68/85
# wuunet_light_224_ow: best_val_bin_acc_480.hdf5
# [wuunet_light_224_ow_best_val_bin_acc_480.hdf5, threshold = 0.55]:
# MULTICLASS JACCARD [val = 0.8629112243652344, std = 0.07925344258546829]
# BINARY JACCARD [val = 0.9036183953285217, std = 0.057923540472984314]
#
# -----------------------------------------------
# 69/85
# wuunet_light_224_ow: best_val_bin_acc_27.hdf5
# [wuunet_light_224_ow_best_val_bin_acc_27.hdf5, threshold = 0.64]:
# MULTICLASS JACCARD [val = 0.750225305557251, std = 0.12510544061660767]
# BINARY JACCARD [val = 0.8077294826507568, std = 0.1113901361823082]
#
# -----------------------------------------------
# 70/85
# wuunet_light_224_ow: best_val_mult_acc_321.hdf5
# [wuunet_light_224_ow_best_val_mult_acc_321.hdf5, threshold = 0.42]:
# MULTICLASS JACCARD [val = 0.8590341806411743, std = 0.08148502558469772]
# BINARY JACCARD [val = 0.9012877941131592, std = 0.059907861053943634]
#
# -----------------------------------------------
# 71/85
# wuunet_light_224_ow: best_val_mult_acc_3.hdf5
# [wuunet_light_224_ow_best_val_mult_acc_3.hdf5, threshold = 0.01]:
# MULTICLASS JACCARD [val = 0.5946792960166931, std = 0.18390542268753052]
# BINARY JACCARD [val = 0.5995634198188782, std = 0.18004067242145538]
#
# -----------------------------------------------
# 72/85
# wuunet_light_224_ow: best_val_bin_acc_577.hdf5
# [wuunet_light_224_ow_best_val_bin_acc_577.hdf5, threshold = 0.58]:
# MULTICLASS JACCARD [val = 0.8675512075424194, std = 0.07897631824016571]
# BINARY JACCARD [val = 0.9060055017471313, std = 0.057441409677267075]
#
# -----------------------------------------------
# 73/85
# wuunet_light_224_ow: best_val_bin_acc_51.hdf5
# [wuunet_light_224_ow_best_val_bin_acc_51.hdf5, threshold = 0.81]:
# MULTICLASS JACCARD [val = 0.816556453704834, std = 0.09680502116680145]
# BINARY JACCARD [val = 0.8631172776222229, std = 0.07701431959867477]
#
# -----------------------------------------------
# 74/85
# wuunet_light_224_ow: best_val_bin_acc_102.hdf5
# [wuunet_light_224_ow_best_val_bin_acc_102.hdf5, threshold = 0.58]:
# MULTICLASS JACCARD [val = 0.840961217880249, std = 0.094781294465065]
# BINARY JACCARD [val = 0.8847618699073792, std = 0.07513344287872314]
#
# -----------------------------------------------
# 75/85
# wuunet_light_224_ow: best_val_bin_acc_273.hdf5
# [wuunet_light_224_ow_best_val_bin_acc_273.hdf5, threshold = 0.26]:
# MULTICLASS JACCARD [val = 0.8548678159713745, std = 0.08148840814828873]
# BINARY JACCARD [val = 0.8983997702598572, std = 0.0576895996928215]
#
# -----------------------------------------------
# 76/85
# wuunet_light_224_ow: best_val_bin_acc_83.hdf5
# [wuunet_light_224_ow_best_val_bin_acc_83.hdf5, threshold = 0.51]:
# MULTICLASS JACCARD [val = 0.8330817222595215, std = 0.09215330332517624]
# BINARY JACCARD [val = 0.8816378116607666, std = 0.06901231408119202]
#
# -----------------------------------------------
# 77/85
# wuunet_light_224_ow: best_val_mult_acc_121.hdf5
# [wuunet_light_224_ow_best_val_mult_acc_121.hdf5, threshold = 0.53]:
# MULTICLASS JACCARD [val = 0.8429304361343384, std = 0.09004025906324387]
# BINARY JACCARD [val = 0.8877112865447998, std = 0.06927629560232162]
#
# -----------------------------------------------
# 78/85
# wuunet_light_224_ow: best_val_bin_acc_64.hdf5
# [wuunet_light_224_ow_best_val_bin_acc_64.hdf5, threshold = 0.53]:
# MULTICLASS JACCARD [val = 0.8252736330032349, std = 0.08881207555532455]
# BINARY JACCARD [val = 0.8696137070655823, std = 0.07000724226236343]
#
# -----------------------------------------------
# 79/85
# wuunet_light_224_ow: best_val_mult_acc_59.hdf5
# [wuunet_light_224_ow_best_val_mult_acc_59.hdf5, threshold = 0.62]:
# MULTICLASS JACCARD [val = 0.8246369361877441, std = 0.0910642072558403]
# BINARY JACCARD [val = 0.869635283946991, std = 0.07205025851726532]
#
# -----------------------------------------------
# 80/85
# wuunet_light_224_ow: best_val_bin_acc_95.hdf5
# [wuunet_light_224_ow_best_val_bin_acc_95.hdf5, threshold = 0.61]:
# MULTICLASS JACCARD [val = 0.8381616473197937, std = 0.09196095168590546]
# BINARY JACCARD [val = 0.8814166784286499, std = 0.07417840510606766]
#
# -----------------------------------------------
# 81/85
# wuunet_light_224_ow: best_val_bin_acc_65.hdf5
# [wuunet_light_224_ow_best_val_bin_acc_65.hdf5, threshold = 0.47000000000000003]:
# MULTICLASS JACCARD [val = 0.8263963460922241, std = 0.08952150493860245]
# BINARY JACCARD [val = 0.871746838092804, std = 0.07001673430204391]
#
# -----------------------------------------------
# 82/85
# wuunet_light_224_ow: best_val_mult_loss_178.hdf5
# [wuunet_light_224_ow_best_val_mult_loss_178.hdf5, threshold = 0.56]:
# MULTICLASS JACCARD [val = 0.8455850481987, std = 0.08833286911249161]
# BINARY JACCARD [val = 0.8897953629493713, std = 0.0668974369764328]
#
# -----------------------------------------------
# 83/85
# wuunet_light_224_ow: best_val_mult_acc_76.hdf5
# [wuunet_light_224_ow_best_val_mult_acc_76.hdf5, threshold = 0.53]:
# MULTICLASS JACCARD [val = 0.8311824202537537, std = 0.08769448846578598]
# BINARY JACCARD [val = 0.8771860599517822, std = 0.06833384931087494]
#
# -----------------------------------------------
# 84/85
# wuunet_light_224_ow: best_val_mult_acc_18.hdf5
# [wuunet_light_224_ow_best_val_mult_acc_18.hdf5, threshold = 0.9500000000000001]:
# MULTICLASS JACCARD [val = 0.7169485688209534, std = 0.14204388856887817]
# BINARY JACCARD [val = 0.7620824575424194, std = 0.12486491352319717]
#
# ================================================
# SUMMARY:
# Jaccard bin  mean max: name = wuunet_light_224_ow_best_val_mult_acc_792.hdf5, value = 0.9111632704734802, thr = 0.25
# Jaccard bin  std min:  name = wuunet_light_224_ow_best_val_mult_loss_811.hdf5, value = 0.05400967597961426, thr = 0.55
# Jaccard mult mean max: name = wuunet_light_224_ow_best_val_mult_acc_792.hdf5, value = 0.8722360134124756, thr = 0.25
# Jaccard mult std min:  name = wuunet_light_224_ow_best_val_mult_acc_792.hdf5, value = 0.07470056414604187, thr = 0.25
# ================================================
